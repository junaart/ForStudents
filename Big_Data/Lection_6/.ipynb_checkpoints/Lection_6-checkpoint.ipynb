# %% [markdown]
# # Лекция 7. Построение кластера MongoDB

# %% [markdown]
# ## Основные компоненты кластера

# %% [markdown]
# До сих пор мы использовали MongoDB как одиночный сервер, то есть каждый экземпляр mongod управлял полной копией данных приложения.
#
# Даже в случае репликации каждая реплика содержит полную копию всех данных – такую же, как на любой другой реплике. Для большинства приложений хранение всего набора данных на одном
# сервере вполне приемлемо.
#
# Но по мере того как объем данных растет, приложение начинает предъявлять более высокие требования к пропускной способности по чтению и записи, и мощности стандартных серверов перестает хватать. В этой ситуации возникает потребность построения кластера.

# %% [markdown]
# Рассмотрим основные компоненты кластера.
#
# <img src="ris1.png">

# %% [markdown]
# Сегментированный кластер состоит из сегментов, маршрутизаторов mongos и конфигурационных серверов.
#
# **Сегменты**
#
# Сегментированный кластер MongoDB распределяет данные по одному или нескольким сегментам. Каждый сегмент развертывается в виде набора реплик, на котором хранится некоторая часть всего множества данных. Поскольку сегмент представляет собой набор реплик, то он поддерживает автоматическую отработку отказов. К отдельному сегменту можно подключаться так же, как к автономному набору реплик. Но если мы подключитесь к одному набору реплик, то
# будете видеть только часть всех данных кластера.
#
# **Маршрутизаторы**
#
# Поскольку каждый сегмент содержит лишь часть данных кластера, то необходим интерфейс для обращения к кластеру как к единому целому. Эту роль выполняют процессы mongos. Каждый такой
# процесс – это маршрутизатор, перенаправляющий все операции чтения и записи подходящему сегменту. За счет этого mongos предоставляет клиентам единый взгляд на систему в целом.
#
# Процессы mongos потребляют мало ресурсов и не отвечают за сохранение данных. Приложение локально соединяется с mongos , а mongos уже управляет соединениями с конкретными сегментами.
#
# **Конфигурационные серверы**
#
# Если процессы mongos не сохраняют данные, то должен быть какой-то компонент, отвечающий за долговременное хранение  состояния сегментированного кластера; этим занимаются
# конфигурационные серверы, которые хранят метаданные кластера.
#
# В состав этих данных входят: глобальная конфигурация кластера, местоположение каждой базы данных, коллекции и диапазоны хранящихся в них данных, а также журнал изменений, в котором сохраняется история миграции данных между сегментами.
#
# Метаданные, хранящиеся на конфигурационных серверах, играют важнейшую роль для правильного функционирования и обслуживания кластера. Например, при каждом запуске процесс mongos
# получает копию метаданных от конфигурационных серверов. Без этих данных невозможно обеспечить согласованное представление сегментированного кластера. Таким образом, важность этих данных диктует стратегию проектирования и развертывания конфигурационных серверов.
#
# В любой производственной системе, где применяется сегментирование, должно быть ровно три конфигурационных сервера, причем для обеспечения резервирования они должны размещаться на разных машинах. Для отправки им данных из процесса mongos применяется протокол двухфазной фиксации, который гарантирует согласованность всех конфигурационных серверов.

# %% [markdown]
# ## Операции сегментирования

# %% [markdown]
# Кластер MongoDB распределяет данные между сегментами на двух уровнях:
# - на уровне базы данных;
# - на уровне коллекции.

# %% [markdown]
# Распределение на уровне базы данных заключается в том, что одна база данных будет вся содержаться в одном сегменте (каждой создаваемой в кластере базе данных назначается свой сегмент).
#
# Сегментирование на уровне коллекции позволяет содержать разные коллекции в разных сегментах.
#
# В MongoDB сегментирование производится по диапазону. Это означает, что для каждого документа в сегментированной коллекции определяется, в какой диапазон попадает значение заданного ключа.
# Чтобы отнести документ к конкретному диапазону, в MongoDB используется так называемый **сегментный ключ (shard key)**. Для создания сегментного ключа можно использовать "_id", однако лучше брать комбинацию полей.
#
# Еще одним важным понятием является  понятие **порции** (chunk). Порция – это непрерывный диапазон значений сегментных ключей, находящихся в одном сегменте.
#
# Важная характеристика порций – это то, что они не физические, а логические. Другими словами, порции не соответствуют последовательность соседних документов на диске.
#
# В основе механизма сегментирования лежит **расщепление и миграция порций**.
#
# Сначала рассмотрим идею расщепления порций. Сразу после настройки сегментированного кластера существует всего одна порция.
# Ее диапазон охватывает всю сегментированную коллекцию.
#
# Порция расщепляется по достижению определенного порогового размера. По умолчанию максимальный размер порции составляет 64 МБ или 100 000 документов, в зависимости от того, что будет достигнуто раньше. По мере добавления данных в новый сегментированный кластер первоначальная порция в конце концов достигает того или другого порога, после чего происходит ее расщепление. Расщепление – простая операция; по существу, она сводится к разбиению исходного диапазона на два поддиапазона и созданию двух новых порций с одинаковым количеством документов в каждой. Расщепление порции – это логическая операция.
# MongoDB просто изменяет метаданные, так что из одной порции получается две. Поэтому расщепление не оказывает влияния на физическое расположение документов в сегментированной коллекции, а,
# значит, происходит быстро.
#
# Одна из самых трудных проблем при проектировании сегментированной системы – обеспечить равномерное балансирование данных. Кластеры MongoDB достигают этого за счет перемещения порций между сегментами. Эта операция называется
# миграцией и, в отличие, от расщепления она подразумевает физические действия.
#
# Миграциями управляет процесс, который называется балансировщиком. Его задача заключается в том, чтобы обеспечить равномерное
# распределение данных между сегментами. Чтобы ее решить, балансировщик учитывает количество порций в каждом сегменте.
#
# Эвристические правила в какой-то мере зависят от полного размера данных, но обычно балансирование производится, когда разность между сегментом с наибольшим количеством порций и сегментом с наименьшим количеством порций оказывается больше восьми. В процессе балансирования порции перемещаются с сегмента, где их больше, на сегмент, где их меньше, пока количество порций не станет примерно одинаковым.

# %% [markdown]
# ## Создание сегментированного кластера

# %% [markdown]
# Сегментированный кластер настраивается в два этапа. На первом запускаются все необходимые процессы mongod и mongos. На втором, более простом, выполняются команды инициализации кластера. Наш кластер будет состоять из двух сегментов и трех конфигурационных серверов. При этом мы запустим всего один процесс mongos для взаимодействия с кластером. На рисунке представлены все рабочие процессы, и для каждого в скобках указан номер порта.
#
# <img src="ris2.png">

# %% [markdown]
# **Инициализация компонентов кластера**
#
# > mkdir /data/a1
#
# > mkdir /data/a2
#
# > mkdir /data/a3
#
# > mkdir /data/b1
#
# > mkdir /data/b2
#
# > mkdir /data/b3
#
# Теперь запустим процессы mongod:
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a1 --port 30000 --logpath ~/data/a1.log --nojournal
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a2 --port 30001 --logpath ~/data/a2.log --nojournal
#
# > mongod --shardsvr --replSet shard-a --dbpath ~/data/a3 --port 30002 --logpath ~/data/a3.log --nojournal
#
#
#
# Также запускаем второй набор реплик:
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b1 --port 30100 --logpath ~/data/b1.log --nojournal
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b2 --port 30101 --logpath ~/data/b2.log --nojournal
#
# > mongod --shardsvr --replSet shard-b --dbpath ~/data/b3 --port 30102 --logpath ~/data/b3.log --nojournal
#
# Наборы реплик необходимо инициализировать, для этого необходимо подключиться к каждому по очереди и выполнить команды:
#
# $ mongo localhost:30000
#
# > rs.initiate()
#
# После того, как данный сервер станет первичным, следует добавить остальные узлы:
#
# > rs.add("localhost:30001")
#
# > rs.addArb("localhost:30002")
#
# Второй набор реплик инициализируется аналогично.
#
# $ mongo localhost:30100
#
# > rs.initiate()
#
# > rs.add("localhost:30101")
#
# > rs.addArb("localhost:30102")
#
# Оба набора реплик можно проверить командой rs.status().
#
# Если на данном этапе все заработало, можно переходить к запуску конфигурационных серверов. Создадим для каждого сервера отдельный каталог, и запустим по одному процессу mongod с параметром configsvr:
#
#
# $ mkdir ~/data/config-1
#
# $ mongod --configsvr --replSet configrs --dbpath ~/data/config-1 --port 27019 --bind_ip localhost
#
# $ mkdir ~/data/config-2
#
# $  mongod --configsvr --replSet configrs --dbpath ~/data/config-2 --port 27020 --bind_ip localhost
#
# $ mkdir ~/data/config-3
#
# $  mongod --configsvr --replSet configrs --dbpath ~/data/config-3 --port 27021 --bind_ip localhost
#
# Зададим настройку реплики
#
# $ mongo --port 27019
#
# > rs.initiate( { _id: "configrs", members: [ { _id : 0, host : "localhost:27019" }, { _id : 1, host : "localhost:27020" }, { _id : 2, host : "localhost:27021" } ] } )
#
# Теперь можно запускать mongos маршрутизатор. При его запуске следует указать параметр configdb,
# значением которого является список адресов конфигурационных баз данных через запятую (или главный сервер реплики):
#
# $ mongos --configdb configrs/localhost:27019 --bind_ip localhost --port 40000

# %% [markdown]
# **Настройка конфигурации**
#
# Теперь все компоненты сегментированного кластера на месте и можно заняться его конфигурированием. Начнем с процесса mongos.
# Чтобы упростить задачу, воспользуемся вспомогательными методами сегментирования. Все они вызываются от имени глобального объекта sh. Чтобы вывести список имеющихся методов, выполните команду sh.help().
#
# Первым делом подключаемся к маршрутизатору и прописываем шарды:
#
# $ mongo --port 40000
#
# > sh.addShard("shard-a/localhost:30000")
#
# > sh.addShard("shard-a/localhost:30001")
#
# > sh.addShard("shard-b/localhost:30100")
#
# > sh.addShard("shard-b/localhost:30101")
#
# Чтобы посмотреть настройку шардирования, можно использовать следующие команды:
#
# > db.getSiblingDB("config").shards.find()
#
# или более кратко:
#
# > use admin
#
# > db.runCommand({listshards: 1})
#
# Более подробную информацию можно получить командой:
#
# > sh.status()
#
# Важным шагом является разрешенние на сегментацию базы данных. Это обязательное условие для сегментирования любой коллекции.
# Назовем нашу базу данных rebus, тогда команда разрешения сегментации выглядит так:
#
# > sh.enableSharding("rebus")
#
# В конфигурационной базе данных имеется коллекция databases , содержащая список баз данных. В каждом документе из этого списка указано местоположение основного сегмента базы и признак partitioned , говорящий о том, сегментирована она или нет.
#
# > use config
#
# > db.databases.find()
#
# { "_id" : "rebus", "primary" : "shard-b", "partitioned" : true }
#
# Теперь можно сегментировать какую-либо коллекцию. При этом определяется сегментный ключ, например, можно использовать составной или простой ключ. Если мы хотим, чтобы ключ  был хэширован, можно вместо этого использовать параметр {"myshardkey":"hashed"}:
#
# > sh.shardCollection("rebus.mycollect", {"_id":"hashed"})
#
# Чтобы посмотреть информацию о шардировании, можно использовать команду:
#
# > db.printShardingStatus()
#
#
# После того как коллекция сегментирована, кластер наконец-то готов к работе. Если теперь мы начнем писать в кластер, то данные будут распределяться по сегментам.

# %% [markdown]
# ## Запись в сегментированный кластер

# %% [markdown]
# Будем писать в сегментированную коллекцию и наблюдать за формированием и перемещением порций, что и составляет суть сегментирования в MongoDB.
#
# Подключаемся к маршрутизатору из Python:

# %%
import pymongo as pm

# Подключение к серверу
client = pm.MongoClient('localhost', 40000)

# Подключение к базе данных
db = client['rebus']

# Получение доступа к коллекции
collection = db['mycollect']

# %%
dir(collection)
# Out:
# ['_BaseObject__codec_options',
#  '_BaseObject__read_concern',
#  '_BaseObject__read_preference',
#  '_BaseObject__write_concern',
#  '_Collection__create',
#  '_Collection__create_indexes',
#  '_Collection__database',
#  '_Collection__find_and_modify',
#  '_Collection__full_name',
#  '_Collection__name',
#  '_Collection__write_response_codec_options',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_aggregate',
#  '_aggregate_one_result',
#  '_command',
#  '_count_cmd',
#  '_delete',
#  '_delete_retryable',
#  '_insert_one',
#  '_is_protocol',
#  '_read_preference_for',
#  '_retryable_non_cursor_read',
#  '_socket_for_reads',
#  '_socket_for_writes',
#  '_update',
#  '_update_retryable',
#  '_write_concern_for',
#  '_write_concern_for_cmd',
#  'aggregate',
#  'aggregate_raw_batches',
#  'bulk_write',
#  'codec_options',
#  'count_documents',
#  'create_index',
#  'create_indexes',
#  'database',
#  'delete_many',
#  'delete_one',
#  'distinct',
#  'drop',
#  'drop_index',
#  'drop_indexes',
#  'estimated_document_count',
#  'find',
#  'find_one',
#  'find_one_and_delete',
#  'find_one_and_replace',
#  'find_one_and_update',
#  'find_raw_batches',
#  'full_name',
#  'index_information',
#  'insert_many',
#  'insert_one',
#  'list_indexes',
#  'name',
#  'next',
#  'options',
#  'read_concern',
#  'read_preference',
#  'rename',
#  'replace_one',
#  'update_many',
#  'update_one',
#  'watch',
#  'with_options',
#  'write_concern']

# %%
collection.insert_one({"_id":35654,'name':"Юрий"})

# %%
[i for i in collection.find()]
# Out:
# [{'_id': 35654, 'name': 'Юрий'}]

# %% [markdown]
# Запишем в коллекцию 200 документов:

# %%
for i in range(600):
    collection.insert_one({'name':"Serge",'age':i})

# %% [markdown]
# Убедимся, что запись в кластер произошла:

# %%
[i for i in collection.find()]
# Out:
# [{'_id': ObjectId('63943fc925e7eb6b1dfa5f9f'), 'name': 'Serge', 'age': 1},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa1'), 'name': 'Serge', 'age': 3},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa2'), 'name': 'Serge', 'age': 4},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa3'), 'name': 'Serge', 'age': 5},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa5'), 'name': 'Serge', 'age': 7},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa7'), 'name': 'Serge', 'age': 9},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa8'), 'name': 'Serge', 'age': 10},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa9'), 'name': 'Serge', 'age': 11},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fae'), 'name': 'Serge', 'age': 16},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5faf'), 'name': 'Serge', 'age': 17},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb0'), 'name': 'Serge', 'age': 18},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb1'), 'name': 'Serge', 'age': 19},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb2'), 'name': 'Serge', 'age': 20},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb3'), 'name': 'Serge', 'age': 21},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb4'), 'name': 'Serge', 'age': 22},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb6'), 'name': 'Serge', 'age': 24},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb7'), 'name': 'Serge', 'age': 25},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb8'), 'name': 'Serge', 'age': 26},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fbb'), 'name': 'Serge', 'age': 29},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fbe'), 'name': 'Serge', 'age': 32},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc0'), 'name': 'Serge', 'age': 34},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc2'), 'name': 'Serge', 'age': 36},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc3'), 'name': 'Serge', 'age': 37},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc4'), 'name': 'Serge', 'age': 38},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc9'), 'name': 'Serge', 'age': 43},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fcb'), 'name': 'Serge', 'age': 45},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fcc'), 'name': 'Serge', 'age': 46},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fcd'), 'name': 'Serge', 'age': 47},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fce'), 'name': 'Serge', 'age': 48},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fcf'), 'name': 'Serge', 'age': 49},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd0'), 'name': 'Serge', 'age': 50},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd1'), 'name': 'Serge', 'age': 51},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd4'), 'name': 'Serge', 'age': 54},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd5'), 'name': 'Serge', 'age': 55},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd7'), 'name': 'Serge', 'age': 57},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd8'), 'name': 'Serge', 'age': 58},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fdc'), 'name': 'Serge', 'age': 62},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fde'), 'name': 'Serge', 'age': 64},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe0'), 'name': 'Serge', 'age': 66},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe2'), 'name': 'Serge', 'age': 68},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe3'), 'name': 'Serge', 'age': 69},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe5'), 'name': 'Serge', 'age': 71},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe8'), 'name': 'Serge', 'age': 74},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fea'), 'name': 'Serge', 'age': 76},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fec'), 'name': 'Serge', 'age': 78},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fef'), 'name': 'Serge', 'age': 81},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff0'), 'name': 'Serge', 'age': 82},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff1'), 'name': 'Serge', 'age': 83},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff4'), 'name': 'Serge', 'age': 86},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff5'), 'name': 'Serge', 'age': 87},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff7'), 'name': 'Serge', 'age': 89},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ffb'), 'name': 'Serge', 'age': 93},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ffc'), 'name': 'Serge', 'age': 94},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6000'), 'name': 'Serge', 'age': 98},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6001'), 'name': 'Serge', 'age': 99},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6006'), 'name': 'Serge', 'age': 104},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6007'), 'name': 'Serge', 'age': 105},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6008'), 'name': 'Serge', 'age': 106},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6009'), 'name': 'Serge', 'age': 107},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600a'), 'name': 'Serge', 'age': 108},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600b'), 'name': 'Serge', 'age': 109},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600e'), 'name': 'Serge', 'age': 112},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6012'), 'name': 'Serge', 'age': 116},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6013'), 'name': 'Serge', 'age': 117},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6014'), 'name': 'Serge', 'age': 118},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6016'), 'name': 'Serge', 'age': 120},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6018'), 'name': 'Serge', 'age': 122},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6019'), 'name': 'Serge', 'age': 123},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601a'), 'name': 'Serge', 'age': 124},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601c'), 'name': 'Serge', 'age': 126},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6020'), 'name': 'Serge', 'age': 130},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6021'), 'name': 'Serge', 'age': 131},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6026'), 'name': 'Serge', 'age': 136},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6027'), 'name': 'Serge', 'age': 137},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602a'), 'name': 'Serge', 'age': 140},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602b'), 'name': 'Serge', 'age': 141},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602c'), 'name': 'Serge', 'age': 142},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602d'), 'name': 'Serge', 'age': 143},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602e'), 'name': 'Serge', 'age': 144},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa602f'), 'name': 'Serge', 'age': 145},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6034'), 'name': 'Serge', 'age': 150},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6035'), 'name': 'Serge', 'age': 151},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6038'), 'name': 'Serge', 'age': 154},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603e'), 'name': 'Serge', 'age': 160},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603f'), 'name': 'Serge', 'age': 161},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6045'), 'name': 'Serge', 'age': 167},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6047'), 'name': 'Serge', 'age': 169},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604b'), 'name': 'Serge', 'age': 173},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604c'), 'name': 'Serge', 'age': 174},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604d'), 'name': 'Serge', 'age': 175},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604f'), 'name': 'Serge', 'age': 177},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6050'), 'name': 'Serge', 'age': 178},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6051'), 'name': 'Serge', 'age': 179},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6053'), 'name': 'Serge', 'age': 181},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6056'), 'name': 'Serge', 'age': 184},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6058'), 'name': 'Serge', 'age': 186},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6059'), 'name': 'Serge', 'age': 187},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605a'), 'name': 'Serge', 'age': 188},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605d'), 'name': 'Serge', 'age': 191},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6060'), 'name': 'Serge', 'age': 194},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6062'), 'name': 'Serge', 'age': 196},
#  {'_id': 35654, 'name': 'Юрий'},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5f9e'), 'name': 'Serge', 'age': 0},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa0'), 'name': 'Serge', 'age': 2},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa4'), 'name': 'Serge', 'age': 6},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fa6'), 'name': 'Serge', 'age': 8},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5faa'), 'name': 'Serge', 'age': 12},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fab'), 'name': 'Serge', 'age': 13},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fac'), 'name': 'Serge', 'age': 14},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fad'), 'name': 'Serge', 'age': 15},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb5'), 'name': 'Serge', 'age': 23},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fb9'), 'name': 'Serge', 'age': 27},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fba'), 'name': 'Serge', 'age': 28},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fbc'), 'name': 'Serge', 'age': 30},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fbd'), 'name': 'Serge', 'age': 31},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fbf'), 'name': 'Serge', 'age': 33},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc1'), 'name': 'Serge', 'age': 35},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc5'), 'name': 'Serge', 'age': 39},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc6'), 'name': 'Serge', 'age': 40},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc7'), 'name': 'Serge', 'age': 41},
#  {'_id': ObjectId('63943fc925e7eb6b1dfa5fc8'), 'name': 'Serge', 'age': 42},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fca'), 'name': 'Serge', 'age': 44},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd2'), 'name': 'Serge', 'age': 52},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd3'), 'name': 'Serge', 'age': 53},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd6'), 'name': 'Serge', 'age': 56},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fd9'), 'name': 'Serge', 'age': 59},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fda'), 'name': 'Serge', 'age': 60},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fdb'), 'name': 'Serge', 'age': 61},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fdd'), 'name': 'Serge', 'age': 63},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fdf'), 'name': 'Serge', 'age': 65},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe1'), 'name': 'Serge', 'age': 67},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe4'), 'name': 'Serge', 'age': 70},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe6'), 'name': 'Serge', 'age': 72},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe7'), 'name': 'Serge', 'age': 73},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fe9'), 'name': 'Serge', 'age': 75},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5feb'), 'name': 'Serge', 'age': 77},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fed'), 'name': 'Serge', 'age': 79},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fee'), 'name': 'Serge', 'age': 80},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff2'), 'name': 'Serge', 'age': 84},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff3'), 'name': 'Serge', 'age': 85},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff6'), 'name': 'Serge', 'age': 88},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff8'), 'name': 'Serge', 'age': 90},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ff9'), 'name': 'Serge', 'age': 91},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ffa'), 'name': 'Serge', 'age': 92},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ffd'), 'name': 'Serge', 'age': 95},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5ffe'), 'name': 'Serge', 'age': 96},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa5fff'), 'name': 'Serge', 'age': 97},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6002'), 'name': 'Serge', 'age': 100},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6003'), 'name': 'Serge', 'age': 101},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6004'), 'name': 'Serge', 'age': 102},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6005'), 'name': 'Serge', 'age': 103},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600c'), 'name': 'Serge', 'age': 110},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600d'), 'name': 'Serge', 'age': 111},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa600f'), 'name': 'Serge', 'age': 113},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6010'), 'name': 'Serge', 'age': 114},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6011'), 'name': 'Serge', 'age': 115},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6015'), 'name': 'Serge', 'age': 119},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6017'), 'name': 'Serge', 'age': 121},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601b'), 'name': 'Serge', 'age': 125},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601d'), 'name': 'Serge', 'age': 127},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601e'), 'name': 'Serge', 'age': 128},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa601f'), 'name': 'Serge', 'age': 129},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6022'), 'name': 'Serge', 'age': 132},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6023'), 'name': 'Serge', 'age': 133},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6024'), 'name': 'Serge', 'age': 134},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6025'), 'name': 'Serge', 'age': 135},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6028'), 'name': 'Serge', 'age': 138},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6029'), 'name': 'Serge', 'age': 139},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6030'), 'name': 'Serge', 'age': 146},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6031'), 'name': 'Serge', 'age': 147},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6032'), 'name': 'Serge', 'age': 148},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6033'), 'name': 'Serge', 'age': 149},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6036'), 'name': 'Serge', 'age': 152},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6037'), 'name': 'Serge', 'age': 153},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6039'), 'name': 'Serge', 'age': 155},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603a'), 'name': 'Serge', 'age': 156},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603b'), 'name': 'Serge', 'age': 157},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603c'), 'name': 'Serge', 'age': 158},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa603d'), 'name': 'Serge', 'age': 159},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6040'), 'name': 'Serge', 'age': 162},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6041'), 'name': 'Serge', 'age': 163},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6042'), 'name': 'Serge', 'age': 164},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6043'), 'name': 'Serge', 'age': 165},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6044'), 'name': 'Serge', 'age': 166},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6046'), 'name': 'Serge', 'age': 168},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6048'), 'name': 'Serge', 'age': 170},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6049'), 'name': 'Serge', 'age': 171},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604a'), 'name': 'Serge', 'age': 172},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa604e'), 'name': 'Serge', 'age': 176},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6052'), 'name': 'Serge', 'age': 180},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6054'), 'name': 'Serge', 'age': 182},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6055'), 'name': 'Serge', 'age': 183},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6057'), 'name': 'Serge', 'age': 185},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605b'), 'name': 'Serge', 'age': 189},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605c'), 'name': 'Serge', 'age': 190},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605e'), 'name': 'Serge', 'age': 192},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa605f'), 'name': 'Serge', 'age': 193},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6061'), 'name': 'Serge', 'age': 195},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6065'), 'name': 'Serge', 'age': 199},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6067'), 'name': 'Serge', 'age': 201},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6069'), 'name': 'Serge', 'age': 203},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa606a'), 'name': 'Serge', 'age': 204},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6063'), 'name': 'Serge', 'age': 197},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6064'), 'name': 'Serge', 'age': 198},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6066'), 'name': 'Serge', 'age': 200},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6068'), 'name': 'Serge', 'age': 202},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa606b'), 'name': 'Serge', 'age': 205},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa606e'), 'name': 'Serge', 'age': 208},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6070'), 'name': 'Serge', 'age': 210},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6072'), 'name': 'Serge', 'age': 212},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6074'), 'name': 'Serge', 'age': 214},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6079'), 'name': 'Serge', 'age': 219},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa607b'), 'name': 'Serge', 'age': 221},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa607c'), 'name': 'Serge', 'age': 222},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa607e'), 'name': 'Serge', 'age': 224},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6081'), 'name': 'Serge', 'age': 227},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6082'), 'name': 'Serge', 'age': 228},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6084'), 'name': 'Serge', 'age': 230},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6085'), 'name': 'Serge', 'age': 231},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6087'), 'name': 'Serge', 'age': 233},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6089'), 'name': 'Serge', 'age': 235},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6091'), 'name': 'Serge', 'age': 243},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6092'), 'name': 'Serge', 'age': 244},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6095'), 'name': 'Serge', 'age': 247},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa6098'), 'name': 'Serge', 'age': 250},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa609c'), 'name': 'Serge', 'age': 254},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa609d'), 'name': 'Serge', 'age': 255},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa609e'), 'name': 'Serge', 'age': 256},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a1'), 'name': 'Serge', 'age': 259},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a4'), 'name': 'Serge', 'age': 262},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a5'), 'name': 'Serge', 'age': 263},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a6'), 'name': 'Serge', 'age': 264},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a7'), 'name': 'Serge', 'age': 265},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60a8'), 'name': 'Serge', 'age': 266},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ab'), 'name': 'Serge', 'age': 269},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ac'), 'name': 'Serge', 'age': 270},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ae'), 'name': 'Serge', 'age': 272},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60b1'), 'name': 'Serge', 'age': 275},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60b2'), 'name': 'Serge', 'age': 276},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60b3'), 'name': 'Serge', 'age': 277},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60b8'), 'name': 'Serge', 'age': 282},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60b9'), 'name': 'Serge', 'age': 283},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ba'), 'name': 'Serge', 'age': 284},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60bd'), 'name': 'Serge', 'age': 287},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60be'), 'name': 'Serge', 'age': 288},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60bf'), 'name': 'Serge', 'age': 289},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60c2'), 'name': 'Serge', 'age': 292},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60c3'), 'name': 'Serge', 'age': 293},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60c5'), 'name': 'Serge', 'age': 295},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ca'), 'name': 'Serge', 'age': 300},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60ce'), 'name': 'Serge', 'age': 304},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60cf'), 'name': 'Serge', 'age': 305},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60d0'), 'name': 'Serge', 'age': 306},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60d3'), 'name': 'Serge', 'age': 309},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60d6'), 'name': 'Serge', 'age': 312},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60d8'), 'name': 'Serge', 'age': 314},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60d9'), 'name': 'Serge', 'age': 315},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60dd'), 'name': 'Serge', 'age': 319},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60de'), 'name': 'Serge', 'age': 320},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e1'), 'name': 'Serge', 'age': 323},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e3'), 'name': 'Serge', 'age': 325},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e4'), 'name': 'Serge', 'age': 326},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e5'), 'name': 'Serge', 'age': 327},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e8'), 'name': 'Serge', 'age': 330},
#  {'_id': ObjectId('63943fca25e7eb6b1dfa60e9'), 'name': 'Serge', 'age': 331},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60f2'), 'name': 'Serge', 'age': 340},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60f5'), 'name': 'Serge', 'age': 343},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60f6'), 'name': 'Serge', 'age': 344},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60f7'), 'name': 'Serge', 'age': 345},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60f8'), 'name': 'Serge', 'age': 346},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60fc'), 'name': 'Serge', 'age': 350},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa60fd'), 'name': 'Serge', 'age': 351},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6100'), 'name': 'Serge', 'age': 354},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6104'), 'name': 'Serge', 'age': 358},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6106'), 'name': 'Serge', 'age': 360},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6107'), 'name': 'Serge', 'age': 361},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6109'), 'name': 'Serge', 'age': 363},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa610d'), 'name': 'Serge', 'age': 367},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa610e'), 'name': 'Serge', 'age': 368},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa610f'), 'name': 'Serge', 'age': 369},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6110'), 'name': 'Serge', 'age': 370},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6113'), 'name': 'Serge', 'age': 373},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6114'), 'name': 'Serge', 'age': 374},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6117'), 'name': 'Serge', 'age': 377},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6118'), 'name': 'Serge', 'age': 378},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6119'), 'name': 'Serge', 'age': 379},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa611b'), 'name': 'Serge', 'age': 381},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa611e'), 'name': 'Serge', 'age': 384},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6121'), 'name': 'Serge', 'age': 387},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6122'), 'name': 'Serge', 'age': 388},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6124'), 'name': 'Serge', 'age': 390},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6125'), 'name': 'Serge', 'age': 391},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6127'), 'name': 'Serge', 'age': 393},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6129'), 'name': 'Serge', 'age': 395},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612a'), 'name': 'Serge', 'age': 396},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612b'), 'name': 'Serge', 'age': 397},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612c'), 'name': 'Serge', 'age': 398},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612d'), 'name': 'Serge', 'age': 399},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612e'), 'name': 'Serge', 'age': 400},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa612f'), 'name': 'Serge', 'age': 401},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6130'), 'name': 'Serge', 'age': 402},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6131'), 'name': 'Serge', 'age': 403},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6132'), 'name': 'Serge', 'age': 404},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6137'), 'name': 'Serge', 'age': 409},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6138'), 'name': 'Serge', 'age': 410},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6139'), 'name': 'Serge', 'age': 411},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa613c'), 'name': 'Serge', 'age': 414},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa613e'), 'name': 'Serge', 'age': 416},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6140'), 'name': 'Serge', 'age': 418},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6142'), 'name': 'Serge', 'age': 420},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa614b'), 'name': 'Serge', 'age': 429},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa614d'), 'name': 'Serge', 'age': 431},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa614f'), 'name': 'Serge', 'age': 433},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6151'), 'name': 'Serge', 'age': 435},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6152'), 'name': 'Serge', 'age': 436},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6154'), 'name': 'Serge', 'age': 438},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6155'), 'name': 'Serge', 'age': 439},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6157'), 'name': 'Serge', 'age': 441},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6158'), 'name': 'Serge', 'age': 442},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6159'), 'name': 'Serge', 'age': 443},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa615a'), 'name': 'Serge', 'age': 444},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa615c'), 'name': 'Serge', 'age': 446},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa615d'), 'name': 'Serge', 'age': 447},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa615f'), 'name': 'Serge', 'age': 449},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6161'), 'name': 'Serge', 'age': 451},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6164'), 'name': 'Serge', 'age': 454},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6165'), 'name': 'Serge', 'age': 455},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6167'), 'name': 'Serge', 'age': 457},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6168'), 'name': 'Serge', 'age': 458},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa616a'), 'name': 'Serge', 'age': 460},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa616b'), 'name': 'Serge', 'age': 461},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa616c'), 'name': 'Serge', 'age': 462},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa616e'), 'name': 'Serge', 'age': 464},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa616f'), 'name': 'Serge', 'age': 465},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6172'), 'name': 'Serge', 'age': 468},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6173'), 'name': 'Serge', 'age': 469},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6174'), 'name': 'Serge', 'age': 470},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6176'), 'name': 'Serge', 'age': 472},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6177'), 'name': 'Serge', 'age': 473},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6178'), 'name': 'Serge', 'age': 474},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6179'), 'name': 'Serge', 'age': 475},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa617a'), 'name': 'Serge', 'age': 476},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa617b'), 'name': 'Serge', 'age': 477},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa617d'), 'name': 'Serge', 'age': 479},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa617e'), 'name': 'Serge', 'age': 480},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa617f'), 'name': 'Serge', 'age': 481},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6181'), 'name': 'Serge', 'age': 483},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6182'), 'name': 'Serge', 'age': 484},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6186'), 'name': 'Serge', 'age': 488},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6188'), 'name': 'Serge', 'age': 490},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa618a'), 'name': 'Serge', 'age': 492},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa618b'), 'name': 'Serge', 'age': 493},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa618c'), 'name': 'Serge', 'age': 494},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa618e'), 'name': 'Serge', 'age': 496},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa618f'), 'name': 'Serge', 'age': 497},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6190'), 'name': 'Serge', 'age': 498},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6191'), 'name': 'Serge', 'age': 499},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6192'), 'name': 'Serge', 'age': 500},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6194'), 'name': 'Serge', 'age': 502},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6197'), 'name': 'Serge', 'age': 505},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6198'), 'name': 'Serge', 'age': 506},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa6199'), 'name': 'Serge', 'age': 507},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa619e'), 'name': 'Serge', 'age': 512},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa619f'), 'name': 'Serge', 'age': 513},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a0'), 'name': 'Serge', 'age': 514},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a2'), 'name': 'Serge', 'age': 516},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a4'), 'name': 'Serge', 'age': 518},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a6'), 'name': 'Serge', 'age': 520},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a7'), 'name': 'Serge', 'age': 521},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61a8'), 'name': 'Serge', 'age': 522},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61aa'), 'name': 'Serge', 'age': 524},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ae'), 'name': 'Serge', 'age': 528},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b0'), 'name': 'Serge', 'age': 530},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b1'), 'name': 'Serge', 'age': 531},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b2'), 'name': 'Serge', 'age': 532},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b5'), 'name': 'Serge', 'age': 535},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b6'), 'name': 'Serge', 'age': 536},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61b8'), 'name': 'Serge', 'age': 538},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ba'), 'name': 'Serge', 'age': 540},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61bb'), 'name': 'Serge', 'age': 541},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61bc'), 'name': 'Serge', 'age': 542},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61bd'), 'name': 'Serge', 'age': 543},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61be'), 'name': 'Serge', 'age': 544},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61bf'), 'name': 'Serge', 'age': 545},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c1'), 'name': 'Serge', 'age': 547},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c2'), 'name': 'Serge', 'age': 548},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c5'), 'name': 'Serge', 'age': 551},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c6'), 'name': 'Serge', 'age': 552},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c7'), 'name': 'Serge', 'age': 553},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61c8'), 'name': 'Serge', 'age': 554},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ca'), 'name': 'Serge', 'age': 556},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61cc'), 'name': 'Serge', 'age': 558},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61cf'), 'name': 'Serge', 'age': 561},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61d0'), 'name': 'Serge', 'age': 562},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61d1'), 'name': 'Serge', 'age': 563},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61d2'), 'name': 'Serge', 'age': 564},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61d6'), 'name': 'Serge', 'age': 568},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61d9'), 'name': 'Serge', 'age': 571},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61da'), 'name': 'Serge', 'age': 572},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61dd'), 'name': 'Serge', 'age': 575},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61e0'), 'name': 'Serge', 'age': 578},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61e1'), 'name': 'Serge', 'age': 579},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61e4'), 'name': 'Serge', 'age': 582},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61e6'), 'name': 'Serge', 'age': 584},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61e9'), 'name': 'Serge', 'age': 587},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ea'), 'name': 'Serge', 'age': 588},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61eb'), 'name': 'Serge', 'age': 589},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ec'), 'name': 'Serge', 'age': 590},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ee'), 'name': 'Serge', 'age': 592},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61ef'), 'name': 'Serge', 'age': 593},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61f1'), 'name': 'Serge', 'age': 595},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61f2'), 'name': 'Serge', 'age': 596},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61f3'), 'name': 'Serge', 'age': 597},
#  {'_id': ObjectId('63943fcb25e7eb6b1dfa61f4'), 'name': 'Serge', 'age': 598},
#  {'_id': ObjectId('6394418b22a4f5e5aca8661f'),
#   'name': 'Max',
#   'amount': 67.72740020597024},
#  {'_id': ObjectId('6394418b22a4f5e5aca86622'),
#   'name': 'Max',
#   'amount': 68.8968187788642},
#  {'_id': ObjectId('6394418b22a4f5e5aca86626'),
#   'name': 'Max',
#   'amount': 62.61007785256004},
#  {'_id': ObjectId('6394418b22a4f5e5aca86627'),
#   'name': 'Max',
#   'amount': 10.185652884867613},
#  {'_id': ObjectId('6394418b22a4f5e5aca86629'),
#   'name': 'Max',
#   'amount': 85.41869510995832},
#  {'_id': ObjectId('6394418b22a4f5e5aca8662b'),
#   'name': 'Max',
#   'amount': 14.108244297000905},
#  {'_id': ObjectId('6394418b22a4f5e5aca86630'),
#   'name': 'Max',
#   'amount': 39.610232989054204},
#  {'_id': ObjectId('6394418b22a4f5e5aca86631'),
#   'name': 'Max',
#   'amount': 24.615152962218247},
#  {'_id': ObjectId('6394418b22a4f5e5aca86634'),
#   'name': 'Max',
#   'amount': 27.690725658676342},
#  {'_id': ObjectId('6394418b22a4f5e5aca86635'),
#   'name': 'Max',
#   'amount': 54.61959384598989},
#  {'_id': ObjectId('6394418b22a4f5e5aca8663a'),
#   'name': 'Max',
#   'amount': 38.57006661309871},
#  {'_id': ObjectId('6394418b22a4f5e5aca8663e'),
#   'name': 'Max',
#   'amount': 23.03524267659003},
#  {'_id': ObjectId('6394418b22a4f5e5aca86640'),
#   'name': 'Max',
#   'amount': 7.9924479699522095},
#  {'_id': ObjectId('6394418b22a4f5e5aca86646'),
#   'name': 'Max',
#   'amount': 44.42374954379667},
#  {'_id': ObjectId('6394418b22a4f5e5aca86647'),
#   'name': 'Max',
#   'amount': 79.86781619440175},
#  {'_id': ObjectId('6394418b22a4f5e5aca8664a'),
#   'name': 'Max',
#   'amount': 71.25114983153793},
#  {'_id': ObjectId('6394418b22a4f5e5aca8664b'),
#   'name': 'Max',
#   'amount': 56.20227152428927},
#  {'_id': ObjectId('6394418b22a4f5e5aca86654'),
#   'name': 'Max',
#   'amount': 55.85458649240746},
#  {'_id': ObjectId('6394418b22a4f5e5aca86657'),
#   'name': 'Max',
#   'amount': 9.961708453115413},
#  {'_id': ObjectId('6394418b22a4f5e5aca86658'),
#   'name': 'Max',
#   'amount': 50.168045967775775},
#  {'_id': ObjectId('6394418b22a4f5e5aca8665c'),
#   'name': 'Max',
#   'amount': 14.293310569799655},
#  {'_id': ObjectId('6394418b22a4f5e5aca86660'),
#   'name': 'Max',
#   'amount': 73.63516417399383},
#  {'_id': ObjectId('6394418b22a4f5e5aca86661'),
#   'name': 'Max',
#   'amount': 67.30297273685026},
#  {'_id': ObjectId('6394418b22a4f5e5aca86662'),
#   'name': 'Max',
#   'amount': 20.067642238462092},
#  {'_id': ObjectId('6394418b22a4f5e5aca86663'),
#   'name': 'Max',
#   'amount': 0.43121173746869523},
#  {'_id': ObjectId('6394418b22a4f5e5aca86669'),
#   'name': 'Max',
#   'amount': 39.377339839734404},
#  {'_id': ObjectId('6394418b22a4f5e5aca8666b'),
#   'name': 'Max',
#   'amount': 45.40671816135523},
#  {'_id': ObjectId('6394418b22a4f5e5aca8666f'),
#   'name': 'Max',
#   'amount': 99.86792635077688},
#  {'_id': ObjectId('6394418b22a4f5e5aca86673'),
#   'name': 'Max',
#   'amount': 43.494424893527075},
#  {'_id': ObjectId('6394418b22a4f5e5aca86675'),
#   'name': 'Max',
#   'amount': 71.90140534753768},
#  {'_id': ObjectId('6394418b22a4f5e5aca86677'),
#   'name': 'Max',
#   'amount': 35.31400713666357},
#  {'_id': ObjectId('6394418b22a4f5e5aca86678'),
#   'name': 'Max',
#   'amount': 28.939095199158317},
#  {'_id': ObjectId('6394418b22a4f5e5aca86679'),
#   'name': 'Max',
#   'amount': 32.4292069269765},
#  {'_id': ObjectId('6394418b22a4f5e5aca8667b'),
#   'name': 'Max',
#   'amount': 47.69668602165651},
#  {'_id': ObjectId('6394418b22a4f5e5aca8667c'),
#   'name': 'Max',
#   'amount': 15.761563754248787},
#  {'_id': ObjectId('6394418b22a4f5e5aca86681'),
#   'name': 'Max',
#   'amount': 7.363484428277056},
#  {'_id': ObjectId('6394418b22a4f5e5aca86683'),
#   'name': 'Max',
#   'amount': 28.17589023353002},
#  {'_id': ObjectId('6394418b22a4f5e5aca86684'),
#   'name': 'Max',
#   'amount': 31.5538424674328},
#  {'_id': ObjectId('6394418b22a4f5e5aca86686'),
#   'name': 'Max',
#   'amount': 45.949107299353976},
#  {'_id': ObjectId('6394418b22a4f5e5aca86687'),
#   'name': 'Max',
#   'amount': 38.11822032949293},
#  {'_id': ObjectId('6394418b22a4f5e5aca86689'),
#   'name': 'Max',
#   'amount': 35.71068934045937},
#  {'_id': ObjectId('6394418b22a4f5e5aca8668a'),
#   'name': 'Max',
#   'amount': 55.49405428911625},
#  {'_id': ObjectId('6394418b22a4f5e5aca8668d'),
#   'name': 'Max',
#   'amount': 15.774356951008006},
#  {'_id': ObjectId('6394418b22a4f5e5aca8668e'),
#   'name': 'Max',
#   'amount': 75.94853280791766},
#  {'_id': ObjectId('6394418b22a4f5e5aca8668f'),
#   'name': 'Max',
#   'amount': 64.50628266731458},
#  {'_id': ObjectId('6394418b22a4f5e5aca86690'),
#   'name': 'Max',
#   'amount': 68.85563962404476},
#  {'_id': ObjectId('6394418b22a4f5e5aca86693'),
#   'name': 'Max',
#   'amount': 95.84312424082698},
#  {'_id': ObjectId('6394418b22a4f5e5aca86697'),
#   'name': 'Max',
#   'amount': 55.060259616894015},
#  {'_id': ObjectId('6394418b22a4f5e5aca86698'),
#   'name': 'Max',
#   'amount': 61.841696009645474},
#  {'_id': ObjectId('6394418b22a4f5e5aca86699'),
#   'name': 'Max',
#   'amount': 47.77019707051179},
#  {'_id': ObjectId('6394418b22a4f5e5aca8669b'),
#   'name': 'Max',
#   'amount': 49.17537938247008},
#  {'_id': ObjectId('6394418b22a4f5e5aca8669d'),
#   'name': 'Max',
#   'amount': 93.01066396695762},
#  {'_id': ObjectId('6394418b22a4f5e5aca8669f'),
#   'name': 'Max',
#   'amount': 20.77835130537391},
#  {'_id': ObjectId('6394418b22a4f5e5aca866a0'),
#   'name': 'Max',
#   'amount': 74.37783836926194},
#  {'_id': ObjectId('6394418b22a4f5e5aca866a2'),
#   'name': 'Max',
#   'amount': 9.965519457346183},
#  {'_id': ObjectId('6394418b22a4f5e5aca866a3'),
#   'name': 'Max',
#   'amount': 66.96384166773329},
#  {'_id': ObjectId('6394418b22a4f5e5aca866a6'),
#   'name': 'Max',
#   'amount': 88.91383706095138},
#  {'_id': ObjectId('6394418b22a4f5e5aca866aa'),
#   'name': 'Max',
#   'amount': 17.923380327306727},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ab'),
#   'name': 'Max',
#   'amount': 60.24202858611311},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ad'),
#   'name': 'Max',
#   'amount': 9.920320492488944},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ae'),
#   'name': 'Max',
#   'amount': 71.14586923631336},
#  {'_id': ObjectId('6394418b22a4f5e5aca866b0'),
#   'name': 'Max',
#   'amount': 37.896639172754206},
#  {'_id': ObjectId('6394418b22a4f5e5aca866b1'),
#   'name': 'Max',
#   'amount': 24.27418773752126},
#  {'_id': ObjectId('6394418b22a4f5e5aca866b2'),
#   'name': 'Max',
#   'amount': 36.177186976592544},
#  {'_id': ObjectId('6394418b22a4f5e5aca866b6'),
#   'name': 'Max',
#   'amount': 79.8757540365238},
#  {'_id': ObjectId('6394418b22a4f5e5aca866b8'),
#   'name': 'Max',
#   'amount': 30.90418505435081},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ba'),
#   'name': 'Max',
#   'amount': 94.52579866153279},
#  {'_id': ObjectId('6394418b22a4f5e5aca866bc'),
#   'name': 'Max',
#   'amount': 33.066740404400086},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c0'),
#   'name': 'Max',
#   'amount': 63.1917836938736},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c2'),
#   'name': 'Max',
#   'amount': 4.952687852728543},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c3'),
#   'name': 'Max',
#   'amount': 2.743767887897275},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c4'),
#   'name': 'Max',
#   'amount': 52.419735961469435},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c6'),
#   'name': 'Max',
#   'amount': 60.78484499992025},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c7'),
#   'name': 'Max',
#   'amount': 66.48814603748501},
#  {'_id': ObjectId('6394418b22a4f5e5aca866c8'),
#   'name': 'Max',
#   'amount': 43.05253916524071},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ca'),
#   'name': 'Max',
#   'amount': 0.862091205002391},
#  {'_id': ObjectId('6394418b22a4f5e5aca866cb'),
#   'name': 'Max',
#   'amount': 33.99157816051475},
#  {'_id': ObjectId('6394418b22a4f5e5aca866cc'),
#   'name': 'Max',
#   'amount': 63.157020696718405},
#  {'_id': ObjectId('6394418b22a4f5e5aca866cd'),
#   'name': 'Max',
#   'amount': 3.3705071244766738},
#  {'_id': ObjectId('6394418b22a4f5e5aca866d2'),
#   'name': 'Max',
#   'amount': 14.43390946350469},
#  {'_id': ObjectId('6394418b22a4f5e5aca866d4'),
#   'name': 'Max',
#   'amount': 79.68051933622576},
#  {'_id': ObjectId('6394418b22a4f5e5aca866d8'),
#   'name': 'Max',
#   'amount': 92.66641566763299},
#  {'_id': ObjectId('6394418b22a4f5e5aca866da'),
#   'name': 'Max',
#   'amount': 7.379168942183345},
#  {'_id': ObjectId('6394418b22a4f5e5aca866dd'),
#   'name': 'Max',
#   'amount': 81.50452575012434},
#  {'_id': ObjectId('6394418b22a4f5e5aca866df'),
#   'name': 'Max',
#   'amount': 66.80609173436581},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e2'),
#   'name': 'Max',
#   'amount': 45.737996510322155},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e3'),
#   'name': 'Max',
#   'amount': 99.79971566425017},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e4'),
#   'name': 'Max',
#   'amount': 30.36177048182571},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e7'),
#   'name': 'Max',
#   'amount': 30.16795020470443},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e8'),
#   'name': 'Max',
#   'amount': 60.09880288289202},
#  {'_id': ObjectId('6394418b22a4f5e5aca866e9'),
#   'name': 'Max',
#   'amount': 35.53392562197774},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ec'),
#   'name': 'Max',
#   'amount': 64.87585991189412},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ef'),
#   'name': 'Max',
#   'amount': 60.41683189048257},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f1'),
#   'name': 'Max',
#   'amount': 58.296932933712206},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f3'),
#   'name': 'Max',
#   'amount': 41.515681566418394},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f4'),
#   'name': 'Max',
#   'amount': 78.01164955859844},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f5'),
#   'name': 'Max',
#   'amount': 14.05259671846214},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f6'),
#   'name': 'Max',
#   'amount': 70.5021782061644},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f8'),
#   'name': 'Max',
#   'amount': 47.26022128024717},
#  {'_id': ObjectId('6394418b22a4f5e5aca866f9'),
#   'name': 'Max',
#   'amount': 93.2000282782272},
#  {'_id': ObjectId('6394418b22a4f5e5aca866fa'),
#   'name': 'Max',
#   'amount': 64.13334143775148},
#  {'_id': ObjectId('6394418b22a4f5e5aca866fb'),
#   'name': 'Max',
#   'amount': 67.04771839991726},
#  {'_id': ObjectId('6394418b22a4f5e5aca866fc'),
#   'name': 'Max',
#   'amount': 62.960842818998906},
#  {'_id': ObjectId('6394418b22a4f5e5aca866fe'),
#   'name': 'Max',
#   'amount': 88.67575890901324},
#  {'_id': ObjectId('6394418b22a4f5e5aca866ff'),
#   'name': 'Max',
#   'amount': 51.253603324996874},
#  {'_id': ObjectId('6394418b22a4f5e5aca86700'),
#   'name': 'Max',
#   'amount': 85.87402502342492},
#  {'_id': ObjectId('6394418b22a4f5e5aca86701'),
#   'name': 'Max',
#   'amount': 44.77928902711288},
#  {'_id': ObjectId('6394418b22a4f5e5aca86703'),
#   'name': 'Max',
#   'amount': 48.59658415645529},
#  {'_id': ObjectId('6394418b22a4f5e5aca86704'),
#   'name': 'Max',
#   'amount': 23.590629698054578},
#  {'_id': ObjectId('6394418b22a4f5e5aca86707'),
#   'name': 'Max',
#   'amount': 21.321292429642924},
#  {'_id': ObjectId('6394418b22a4f5e5aca8670b'),
#   'name': 'Max',
#   'amount': 36.59650975220169},
#  {'_id': ObjectId('6394418b22a4f5e5aca8670f'),
#   'name': 'Max',
#   'amount': 85.03718536260097},
#  {'_id': ObjectId('6394418b22a4f5e5aca86710'),
#   'name': 'Max',
#   'amount': 14.570232300017839},
#  {'_id': ObjectId('6394418b22a4f5e5aca86711'),
#   'name': 'Max',
#   'amount': 41.46043886148867},
#  {'_id': ObjectId('6394418b22a4f5e5aca86714'),
#   'name': 'Max',
#   'amount': 10.319450027966449},
#  {'_id': ObjectId('6394418b22a4f5e5aca86715'),
#   'name': 'Max',
#   'amount': 9.4622749641598},
#  {'_id': ObjectId('6394418b22a4f5e5aca86719'),
#   'name': 'Max',
#   'amount': 87.05918985219319},
#  {'_id': ObjectId('6394418b22a4f5e5aca8671c'),
#   'name': 'Max',
#   'amount': 42.129420230420024},
#  {'_id': ObjectId('6394418b22a4f5e5aca8671d'),
#   'name': 'Max',
#   'amount': 49.47703027764566},
#  {'_id': ObjectId('6394418b22a4f5e5aca86724'),
#   'name': 'Max',
#   'amount': 90.63954411228988},
#  {'_id': ObjectId('6394418b22a4f5e5aca86725'),
#   'name': 'Max',
#   'amount': 27.27141908456836},
#  {'_id': ObjectId('6394418b22a4f5e5aca86726'),
#   'name': 'Max',
#   'amount': 41.26593111304131},
#  {'_id': ObjectId('6394418b22a4f5e5aca8672a'),
#   'name': 'Max',
#   'amount': 75.5829781442061},
#  {'_id': ObjectId('6394418b22a4f5e5aca8672b'),
#   'name': 'Max',
#   'amount': 1.5751042290440442},
#  {'_id': ObjectId('6394418b22a4f5e5aca8672c'),
#   'name': 'Max',
#   'amount': 51.30864802295626},
#  {'_id': ObjectId('6394418b22a4f5e5aca8672d'),
#   'name': 'Max',
#   'amount': 32.593002753418645},
#  {'_id': ObjectId('6394418b22a4f5e5aca8672e'),
#   'name': 'Max',
#   'amount': 17.244740523615132},
#  {'_id': ObjectId('6394418b22a4f5e5aca86732'),
#   'name': 'Max',
#   'amount': 29.490787877420143},
#  {'_id': ObjectId('6394418b22a4f5e5aca86733'),
#   'name': 'Max',
#   'amount': 13.01760767929807},
#  {'_id': ObjectId('6394418b22a4f5e5aca86734'),
#   'name': 'Max',
#   'amount': 43.45439163845122},
#  {'_id': ObjectId('6394418b22a4f5e5aca86737'),
#   'name': 'Max',
#   'amount': 14.527853193612629},
#  {'_id': ObjectId('6394418b22a4f5e5aca86738'),
#   'name': 'Max',
#   'amount': 68.62896678997136},
#  {'_id': ObjectId('6394418b22a4f5e5aca86741'),
#   'name': 'Max',
#   'amount': 71.8572472433814},
#  {'_id': ObjectId('6394418b22a4f5e5aca86742'),
#   'name': 'Max',
#   'amount': 9.999752925501548},
#  {'_id': ObjectId('6394418b22a4f5e5aca86744'),
#   'name': 'Max',
#   'amount': 1.1141152206331162},
#  {'_id': ObjectId('6394418b22a4f5e5aca86746'),
#   'name': 'Max',
#   'amount': 85.57476815773911},
#  {'_id': ObjectId('6394418b22a4f5e5aca86748'),
#   'name': 'Max',
#   'amount': 13.853819371892072},
#  {'_id': ObjectId('6394418b22a4f5e5aca8674a'),
#   'name': 'Max',
#   'amount': 69.96975858371775},
#  {'_id': ObjectId('6394418b22a4f5e5aca8674c'),
#   'name': 'Max',
#   'amount': 10.215484591350732},
#  {'_id': ObjectId('6394418b22a4f5e5aca8674d'),
#   'name': 'Max',
#   'amount': 62.912554693628685},
#  {'_id': ObjectId('6394418b22a4f5e5aca86750'),
#   'name': 'Max',
#   'amount': 50.99949610430284},
#  {'_id': ObjectId('6394418b22a4f5e5aca86752'),
#   'name': 'Max',
#   'amount': 76.3078906093667},
#  {'_id': ObjectId('6394418b22a4f5e5aca86755'),
#   'name': 'Max',
#   'amount': 33.519864300326674},
#  {'_id': ObjectId('6394418b22a4f5e5aca86756'),
#   'name': 'Max',
#   'amount': 32.589650298512396},
#  {'_id': ObjectId('6394418b22a4f5e5aca86757'),
#   'name': 'Max',
#   'amount': 1.0914000136258206},
#  {'_id': ObjectId('6394418b22a4f5e5aca8675a'),
#   'name': 'Max',
#   'amount': 65.4608945008808},
#  {'_id': ObjectId('6394418c22a4f5e5aca8675e'),
#   'name': 'Max',
#   'amount': 87.45992474982181},
#  {'_id': ObjectId('6394418c22a4f5e5aca86761'),
#   'name': 'Max',
#   'amount': 78.24482487981011},
#  {'_id': ObjectId('6394418c22a4f5e5aca86762'),
#   'name': 'Max',
#   'amount': 9.454289482946033},
#  {'_id': ObjectId('6394418c22a4f5e5aca86764'),
#   'name': 'Max',
#   'amount': 92.06217333665448},
#  {'_id': ObjectId('6394418c22a4f5e5aca86765'),
#   'name': 'Max',
#   'amount': 86.70663656134616},
#  {'_id': ObjectId('6394418c22a4f5e5aca86766'),
#   'name': 'Max',
#   'amount': 26.801267617200295},
#  {'_id': ObjectId('6394418c22a4f5e5aca86767'),
#   'name': 'Max',
#   'amount': 5.482562392565072},
#  {'_id': ObjectId('6394418c22a4f5e5aca86769'),
#   'name': 'Max',
#   'amount': 62.4720226531971},
#  {'_id': ObjectId('6394418c22a4f5e5aca8676d'),
#   'name': 'Max',
#   'amount': 2.1442019937818024},
#  {'_id': ObjectId('6394418c22a4f5e5aca8676f'),
#   'name': 'Max',
#   'amount': 54.847590220730766},
#  {'_id': ObjectId('6394418c22a4f5e5aca86770'),
#   'name': 'Max',
#   'amount': 84.67807343742862},
#  {'_id': ObjectId('6394418c22a4f5e5aca86771'),
#   'name': 'Max',
#   'amount': 14.176466709647674},
#  {'_id': ObjectId('6394418c22a4f5e5aca86773'),
#   'name': 'Max',
#   'amount': 58.44217075195728},
#  {'_id': ObjectId('6394418c22a4f5e5aca86776'),
#   'name': 'Max',
#   'amount': 89.94358879360308},
#  {'_id': ObjectId('6394418c22a4f5e5aca86777'),
#   'name': 'Max',
#   'amount': 47.5243022250442},
#  {'_id': ObjectId('6394418c22a4f5e5aca86778'),
#   'name': 'Max',
#   'amount': 52.208314723806396},
#  {'_id': ObjectId('6394418c22a4f5e5aca86779'),
#   'name': 'Max',
#   'amount': 55.533927080890436},
#  {'_id': ObjectId('6394418c22a4f5e5aca8677b'),
#   'name': 'Max',
#   'amount': 84.0175025753247},
#  {'_id': ObjectId('6394418c22a4f5e5aca8677c'),
#   'name': 'Max',
#   'amount': 80.72659157885698},
#  {'_id': ObjectId('6394418c22a4f5e5aca8677d'),
#   'name': 'Max',
#   'amount': 52.95532942098317},
#  {'_id': ObjectId('6394418c22a4f5e5aca8677f'),
#   'name': 'Max',
#   'amount': 98.061568195306},
#  {'_id': ObjectId('6394418c22a4f5e5aca86783'),
#   'name': 'Max',
#   'amount': 58.1232598737831},
#  {'_id': ObjectId('6394418c22a4f5e5aca86784'),
#   'name': 'Max',
#   'amount': 79.92420335258525},
# ...
#   'amount': 70.1181264173912},
#  {'_id': ObjectId('6394418d22a4f5e5aca86975'),
#   'name': 'Max',
#   'amount': 73.53828039579365},
#  {'_id': ObjectId('6394418d22a4f5e5aca86976'),
#   'name': 'Max',
#   'amount': 29.190760618102384},
#  {'_id': ObjectId('6394418d22a4f5e5aca8697a'),
#   'name': 'Max',
#   'amount': 47.153598154014055},
#  {'_id': ObjectId('6394418d22a4f5e5aca8697b'),
#   'name': 'Max',
#   'amount': 95.41629102170364},
#  {'_id': ObjectId('6394418d22a4f5e5aca8697e'),
#   'name': 'Max',
#   'amount': 96.96383590556789},
#  {'_id': ObjectId('6394418d22a4f5e5aca8697f'),
#   'name': 'Max',
#   'amount': 32.667123121120426},
#  {'_id': ObjectId('6394418d22a4f5e5aca86985'),
#   'name': 'Max',
#   'amount': 94.11514690673009},
#  {'_id': ObjectId('6394418d22a4f5e5aca86988'),
#   'name': 'Max',
#   'amount': 22.014848304838843},
#  {'_id': ObjectId('6394418d22a4f5e5aca8698a'),
#   'name': 'Max',
#   'amount': 41.749423100050656},
#  {'_id': ObjectId('6394418d22a4f5e5aca8698c'),
#   'name': 'Max',
#   'amount': 40.737859614937854},
#  {'_id': ObjectId('6394418d22a4f5e5aca8698d'),
#   'name': 'Max',
#   'amount': 90.71169454080244},
#  {'_id': ObjectId('6394418d22a4f5e5aca86990'),
#   'name': 'Max',
#   'amount': 42.74829952856699},
#  {'_id': ObjectId('6394418d22a4f5e5aca86995'),
#   'name': 'Max',
#   'amount': 79.6557885259678},
#  {'_id': ObjectId('6394418d22a4f5e5aca86998'),
#   'name': 'Max',
#   'amount': 87.77894153782363},
#  {'_id': ObjectId('6394418d22a4f5e5aca86999'),
#   'name': 'Max',
#   'amount': 89.95450410648799},
#  {'_id': ObjectId('6394418d22a4f5e5aca8699a'),
#   'name': 'Max',
#   'amount': 46.865488019910494},
#  {'_id': ObjectId('6394418d22a4f5e5aca8699c'),
#   'name': 'Max',
#   'amount': 23.67969808231216},
#  {'_id': ObjectId('6394418d22a4f5e5aca8699e'),
#   'name': 'Max',
#   'amount': 64.08520978460047},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a1'),
#   'name': 'Max',
#   'amount': 10.183899063338364},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a3'),
#   'name': 'Max',
#   'amount': 14.740612331993342},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a4'),
#   'name': 'Max',
#   'amount': 44.258314741591676},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a6'),
#   'name': 'Max',
#   'amount': 40.80140784953989},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a7'),
#   'name': 'Max',
#   'amount': 2.545956773431679},
#  {'_id': ObjectId('6394418d22a4f5e5aca869a8'),
#   'name': 'Max',
#   'amount': 46.28103249827495},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ad'),
#   'name': 'Max',
#   'amount': 8.842822679854901},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ae'),
#   'name': 'Max',
#   'amount': 74.93725735034695},
#  {'_id': ObjectId('6394418d22a4f5e5aca869af'),
#   'name': 'Max',
#   'amount': 42.57105927423226},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b0'),
#   'name': 'Max',
#   'amount': 93.24704870783381},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b2'),
#   'name': 'Max',
#   'amount': 42.86105122555727},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b3'),
#   'name': 'Max',
#   'amount': 99.4020320932051},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b4'),
#   'name': 'Max',
#   'amount': 99.99023356974457},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b5'),
#   'name': 'Max',
#   'amount': 19.16658914209346},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b6'),
#   'name': 'Max',
#   'amount': 82.8808973347657},
#  {'_id': ObjectId('6394418d22a4f5e5aca869b7'),
#   'name': 'Max',
#   'amount': 67.3506667448534},
#  {'_id': ObjectId('6394418d22a4f5e5aca869bd'),
#   'name': 'Max',
#   'amount': 31.497006147817675},
#  {'_id': ObjectId('6394418d22a4f5e5aca869c1'),
#   'name': 'Max',
#   'amount': 10.6958066761349},
#  {'_id': ObjectId('6394418d22a4f5e5aca869c3'),
#   'name': 'Max',
#   'amount': 97.18577819098591},
#  {'_id': ObjectId('6394418d22a4f5e5aca869c4'),
#   'name': 'Max',
#   'amount': 11.892015734348893},
#  {'_id': ObjectId('6394418d22a4f5e5aca869c7'),
#   'name': 'Max',
#   'amount': 68.58644854039426},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ca'),
#   'name': 'Max',
#   'amount': 0.37780027048935905},
#  {'_id': ObjectId('6394418d22a4f5e5aca869cb'),
#   'name': 'Max',
#   'amount': 96.37030423464604},
#  {'_id': ObjectId('6394418d22a4f5e5aca869cc'),
#   'name': 'Max',
#   'amount': 64.07306537635603},
#  {'_id': ObjectId('6394418d22a4f5e5aca869cf'),
#   'name': 'Max',
#   'amount': 91.55867160147943},
#  {'_id': ObjectId('6394418d22a4f5e5aca869d1'),
#   'name': 'Max',
#   'amount': 21.775415383125075},
#  {'_id': ObjectId('6394418d22a4f5e5aca869d4'),
#   'name': 'Max',
#   'amount': 48.18507799116949},
#  {'_id': ObjectId('6394418d22a4f5e5aca869d6'),
#   'name': 'Max',
#   'amount': 73.54043136721836},
#  {'_id': ObjectId('6394418d22a4f5e5aca869d7'),
#   'name': 'Max',
#   'amount': 78.0263521998032},
#  {'_id': ObjectId('6394418d22a4f5e5aca869d8'),
#   'name': 'Max',
#   'amount': 51.91006791185823},
#  {'_id': ObjectId('6394418d22a4f5e5aca869da'),
#   'name': 'Max',
#   'amount': 55.80720792124968},
#  {'_id': ObjectId('6394418d22a4f5e5aca869de'),
#   'name': 'Max',
#   'amount': 37.7073155510875},
#  {'_id': ObjectId('6394418d22a4f5e5aca869df'),
#   'name': 'Max',
#   'amount': 15.827855274582593},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e0'),
#   'name': 'Max',
#   'amount': 82.6630241413798},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e2'),
#   'name': 'Max',
#   'amount': 66.47534302190323},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e3'),
#   'name': 'Max',
#   'amount': 98.95545214277391},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e5'),
#   'name': 'Max',
#   'amount': 43.44749009621035},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e6'),
#   'name': 'Max',
#   'amount': 9.236745730636287},
#  {'_id': ObjectId('6394418d22a4f5e5aca869e7'),
#   'name': 'Max',
#   'amount': 32.87189342975741},
#  {'_id': ObjectId('6394418d22a4f5e5aca869eb'),
#   'name': 'Max',
#   'amount': 77.91669400270659},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ec'),
#   'name': 'Max',
#   'amount': 9.477966883568223},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ed'),
#   'name': 'Max',
#   'amount': 21.40201669267118},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ee'),
#   'name': 'Max',
#   'amount': 57.01622391584992},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ef'),
#   'name': 'Max',
#   'amount': 75.59573432259491},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f2'),
#   'name': 'Max',
#   'amount': 59.257233685023635},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f3'),
#   'name': 'Max',
#   'amount': 63.62620874120194},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f4'),
#   'name': 'Max',
#   'amount': 72.24158281036912},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f7'),
#   'name': 'Max',
#   'amount': 52.48163435043275},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f8'),
#   'name': 'Max',
#   'amount': 80.30191359749703},
#  {'_id': ObjectId('6394418d22a4f5e5aca869f9'),
#   'name': 'Max',
#   'amount': 6.303755516257603},
#  {'_id': ObjectId('6394418d22a4f5e5aca869fa'),
#   'name': 'Max',
#   'amount': 51.13689198563027},
#  {'_id': ObjectId('6394418d22a4f5e5aca869fe'),
#   'name': 'Max',
#   'amount': 11.732962642929134},
#  {'_id': ObjectId('6394418d22a4f5e5aca869ff'),
#   'name': 'Max',
#   'amount': 86.24631480239076},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a04'),
#   'name': 'Max',
#   'amount': 12.148271773219543},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a06'),
#   'name': 'Max',
#   'amount': 55.66894562246073},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a08'),
#   'name': 'Max',
#   'amount': 18.13430144048993},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a0e'),
#   'name': 'Max',
#   'amount': 45.37583284191962},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a10'),
#   'name': 'Max',
#   'amount': 70.321802286072},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a14'),
#   'name': 'Max',
#   'amount': 31.092287832208708},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a15'),
#   'name': 'Max',
#   'amount': 19.277981399727405},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a16'),
#   'name': 'Max',
#   'amount': 22.13339926042954},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a17'),
#   'name': 'Max',
#   'amount': 30.659131309015898},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a1d'),
#   'name': 'Max',
#   'amount': 29.591232735058092},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a20'),
#   'name': 'Max',
#   'amount': 91.76419344681076},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a22'),
#   'name': 'Max',
#   'amount': 96.85478807516985},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a28'),
#   'name': 'Max',
#   'amount': 52.6751552880212},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a29'),
#   'name': 'Max',
#   'amount': 80.99559061787188},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a2b'),
#   'name': 'Max',
#   'amount': 26.3785915191723},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a2e'),
#   'name': 'Max',
#   'amount': 7.803392995674963},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a2f'),
#   'name': 'Max',
#   'amount': 3.5174676815944217},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a31'),
#   'name': 'Max',
#   'amount': 48.11004276724038},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a33'),
#   'name': 'Max',
#   'amount': 29.993634601921602},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a34'),
#   'name': 'Max',
#   'amount': 49.66713250300031},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a35'),
#   'name': 'Max',
#   'amount': 74.89359237171568},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a37'),
#   'name': 'Max',
#   'amount': 83.82943329546437},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a38'),
#   'name': 'Max',
#   'amount': 74.88116538879245},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a3c'),
#   'name': 'Max',
#   'amount': 34.42563323577906},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a3e'),
#   'name': 'Max',
#   'amount': 19.0979236003904},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a42'),
#   'name': 'Max',
#   'amount': 42.97313630618967},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a45'),
#   'name': 'Max',
#   'amount': 87.76648993536921},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a48'),
#   'name': 'Max',
#   'amount': 99.93198449223839},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a49'),
#   'name': 'Max',
#   'amount': 84.34419955028439},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a4e'),
#   'name': 'Max',
#   'amount': 35.988692632706865},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a51'),
#   'name': 'Max',
#   'amount': 23.258612807810586},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a52'),
#   'name': 'Max',
#   'amount': 18.84325771846711},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a54'),
#   'name': 'Max',
#   'amount': 69.78482549535214},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a55'),
#   'name': 'Max',
#   'amount': 17.897481616602594},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a56'),
#   'name': 'Max',
#   'amount': 43.570912507191764},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a59'),
#   'name': 'Max',
#   'amount': 10.108050095802145},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a5b'),
#   'name': 'Max',
#   'amount': 65.34286107396177},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a5c'),
#   'name': 'Max',
#   'amount': 60.96411825804399},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a5f'),
#   'name': 'Max',
#   'amount': 26.19806691924663},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a62'),
#   'name': 'Max',
#   'amount': 62.159464439291035},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a66'),
#   'name': 'Max',
#   'amount': 79.78168002596075},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a69'),
#   'name': 'Max',
#   'amount': 34.623489263245865},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a6a'),
#   'name': 'Max',
#   'amount': 34.4798227990828},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a6b'),
#   'name': 'Max',
#   'amount': 27.531078614848916},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a6c'),
#   'name': 'Max',
#   'amount': 75.74453369942195},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a6d'),
#   'name': 'Max',
#   'amount': 68.5322826598206},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a71'),
#   'name': 'Max',
#   'amount': 28.511897782438012},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a72'),
#   'name': 'Max',
#   'amount': 11.053704146960486},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a73'),
#   'name': 'Max',
#   'amount': 2.958741435427148},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a76'),
#   'name': 'Max',
#   'amount': 36.17591617891045},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a7d'),
#   'name': 'Max',
#   'amount': 17.250345202865557},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a7e'),
#   'name': 'Max',
#   'amount': 77.11696309659948},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a7f'),
#   'name': 'Max',
#   'amount': 24.579526033237407},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a80'),
#   'name': 'Max',
#   'amount': 23.85114720301531},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a83'),
#   'name': 'Max',
#   'amount': 91.62498742504737},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a85'),
#   'name': 'Max',
#   'amount': 32.49149799204378},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a86'),
#   'name': 'Max',
#   'amount': 53.49917530937019},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a87'),
#   'name': 'Max',
#   'amount': 61.37167125113978},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a8b'),
#   'name': 'Max',
#   'amount': 69.76272696939517},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a8d'),
#   'name': 'Max',
#   'amount': 32.74278015910023},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a8e'),
#   'name': 'Max',
#   'amount': 23.561733618479174},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a8f'),
#   'name': 'Max',
#   'amount': 50.32687814496235},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a91'),
#   'name': 'Max',
#   'amount': 75.89677664083041},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a92'),
#   'name': 'Max',
#   'amount': 22.070268766326063},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a94'),
#   'name': 'Max',
#   'amount': 5.639695923613153},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a99'),
#   'name': 'Max',
#   'amount': 99.94150771713394},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a9d'),
#   'name': 'Max',
#   'amount': 86.45382411911964},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a9e'),
#   'name': 'Max',
#   'amount': 72.92886457046549},
#  {'_id': ObjectId('6394418d22a4f5e5aca86a9f'),
#   'name': 'Max',
#   'amount': 45.664334976548574},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aa2'),
#   'name': 'Max',
#   'amount': 93.94801819016956},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aa3'),
#   'name': 'Max',
#   'amount': 42.90243563247436},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aa5'),
#   'name': 'Max',
#   'amount': 87.5561009514485},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aa9'),
#   'name': 'Max',
#   'amount': 95.28221773458485},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aaa'),
#   'name': 'Max',
#   'amount': 46.08948892104275},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aab'),
#   'name': 'Max',
#   'amount': 76.89175835349863},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aac'),
#   'name': 'Max',
#   'amount': 89.2928143718233},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aad'),
#   'name': 'Max',
#   'amount': 67.18320169083765},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ab0'),
#   'name': 'Max',
#   'amount': 44.94186233789633},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ab1'),
#   'name': 'Max',
#   'amount': 42.00551710820912},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ab3'),
#   'name': 'Max',
#   'amount': 17.83295658958255},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ab5'),
#   'name': 'Max',
#   'amount': 10.968098638177725},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ab8'),
#   'name': 'Max',
#   'amount': 47.91048916765826},
#  {'_id': ObjectId('6394418d22a4f5e5aca86aba'),
#   'name': 'Max',
#   'amount': 40.669646310412425},
#  {'_id': ObjectId('6394418d22a4f5e5aca86abb'),
#   'name': 'Max',
#   'amount': 48.837755833431984},
#  {'_id': ObjectId('6394418d22a4f5e5aca86abd'),
#   'name': 'Max',
#   'amount': 21.29579150433939},
#  {'_id': ObjectId('6394418d22a4f5e5aca86abe'),
#   'name': 'Max',
#   'amount': 32.68004841225601},
#  {'_id': ObjectId('6394418d22a4f5e5aca86abf'),
#   'name': 'Max',
#   'amount': 57.70851486308263},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ac0'),
#   'name': 'Max',
#   'amount': 41.22499459182231},
#  {'_id': ObjectId('6394418d22a4f5e5aca86ac1'),
#   'name': 'Max',
#   'amount': 80.12349688066249},
#  {'_id': ObjectId('6394418e22a4f5e5aca86ac3'),
#   'name': 'Max',
#   'amount': 47.641460001554805},
#  {'_id': ObjectId('6394418e22a4f5e5aca86ac4'),
#   'name': 'Max',
#   'amount': 99.94059054000672},
#  {'_id': ObjectId('6394418e22a4f5e5aca86ac7'),
#   'name': 'Max',
#   'amount': 19.886199177857733},
#  {'_id': ObjectId('6394418e22a4f5e5aca86ac9'),
#   'name': 'Max',
#   'amount': 77.228979407938},
#  {'_id': ObjectId('6394418e22a4f5e5aca86acb'),
#   'name': 'Max',
#   'amount': 69.21783781955828},
#  {'_id': ObjectId('6394418e22a4f5e5aca86acd'),
#   'name': 'Max',
#   'amount': 60.88160442115724},
#  ...]

# %% [markdown]
# Теперь можно посмотреть, что произошло с кластером. Для этого можно переключиться на базу данных config и запросить количество порций :
#
# > use config
#
# > db.chunks.count()
#
# Рассмотрим количество документов, которые были добавлены:
#
# > db.mycollect.count()
#
# Рассмотрим объем памяти, занятый данными:
#
# > db.mycollect.stats().size
#
# Для получения более детальной информации вызовем метод sh.status(), который напечатает все порции с указанием их диапазонов.
#
# > sh.status()
#
# Можно попробовать добавлять документы прямо в консоле:
#
# > use rebus
#
# > for (var i=0; i<2100000; i++) { db.mycollect.insert({name: "Max", amount:Math.random()*100})}
#
# Чтобы посмотреть, сколько порций выделено в каждом сегменте, можно использовать команды:
#
# > db.chunks.count({"shard": "shard-a"})
#
# > db.chunks.count({"shard": "shard-b"})
