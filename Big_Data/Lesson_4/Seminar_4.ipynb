# %% [markdown]
# # Практика 4

# %% [markdown]
# В наборе данных data.xlsx представлены характеристики банков по показателям: уставной капитал, работающие активы, капитал. Все показатели в млрд. руб.
#
# 1. Распределить банки на группы по величине уставного капитала, по активам, по капиталу, построить гистограммы. Сохранить полученные группировки в виде DataFrame.
# 2. Определить объемные показатели по каждой группе при группировке по величине уставного капитала: суммарные, средние работающие активы группы, а также размах вариации, среднее линейное отклонение, межквартильный размах внутри каждой группы. Результаты расчета оформить в виде DataFrame с его последующим сохранением.
# 3. Определить объемные показатели по каждой группе при группировке по капиталу: суммарный, средний, медианный  капитал, а также дисперсию, среднее квадратическое отклонение, среднее линейное отклонение от медианного значения, относительные показатели вариации: коэффициент осцилляции, коэффициент вариации внутри каждой группы. Результаты расчета оформить в виде DataFrame с его последующим сохранением.
# 4. Рассчитать средние показатели и показатели вариации по несгруппированным данным: среднее арифметическое, среднее геометрическое, среднее геометрическое, медиана, дисперию, среднее квадратическое отклонение, коэффициент вариации по показателям капитала, уставного капитала, работающих активов. Построить для них диаграмму "ящик с усами" Сделать выводы об однородности статистических совокупностей. Сравнить показатели вариации на несгруппированной совокупности с показателями вариации на сгруппированных совокупностях.
# 5. Оценить коэффициенты ассиметрии и эксцесса по показателям капитала, уставного капитала, работающих активов.
# 6. Рассчитать эмпирическое корреляционное отношение между величиной уставного капитала и работающими активами
# 7. Рассчитать и отображить корреляционную матрицу с использованием коэффициентов корреляции Пирсона, Спирмена и Кендалла, оценить их статистическую значимость.

# %% [markdown]
# # Задание для самостоятельного решения

# %% [markdown]
# 1. Загрузить датасет 'HairEyeColor', который содержит статистическую информацию о зависимостях между цветом волос, глаз и полом.
# 2. Используя механизм сводных таблиц, определить суммарное количество мужчин и женщин, участвующих в опросе.
# 3. Используя механизм сводных таблиц, определить суммарное количество мужчин и женщин,  участвующих в опросе, в градации по цвету волос.
# 4. Определить, кого больше - мужчин или женщин с зелёными глазами?
# 5. Сколько всего человек приняло участие в опросе?
# 6. Постройте гистограмму распределения людей по цвету волос, определите модальное значение.
# 7. Постройте гистограмму распределения мужчин по цвету волос,определите модальное значение.
# 8. Постройте гистограмму распределения женщин по цвету волос, определите модальное значение.
# 9. Постройте гистограмму распределения людей по цвету глаз, определите модальное значение.
# 10. Постройте гистограмму распределения мужчин по цвету глаз,определите модальное значение.
# 11. Постройте гистограмму распределения женщин по цвету глаз, определите модальное значение.
#
# 12. Используя данные о населении Канады (датасет CanPop), определить среднее арифметическое, гармоническое, геометрическое, медианное значения численности населения по годам.
# 13. Построить гистограмму численности по годам.
# 14. Определить перечень годов, которые находятся между первым и третьем квартилями численности населения.
# 15. Рассчитать скользящее среднее - учитывая по три года, изобразить полученные значения в виде графика.
