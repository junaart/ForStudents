# %% [markdown]
# # **Вопросы к экзамену**

# %% [markdown]
#     1. Общие понятия о больших данных, наука о данных.
#     2. Понятия дескриптивной, диагностической, прогностической, прескриптивной  аналитик.
#     3. Основные этапы жизненного цикла аналитики больших данных.
#     4. Основные методы анализа больших данных.
#     5. Обзор основных программных средств анализа больших данных.
#     6. Ограничения CAP теоремы.
#     7. Понятие NoSQL, классификация NoSQL-решений.
#     8. Распределенные хранилища данных. Технологии шардинга, репликации, MapReduce.
#     9. Типы структурированных данных.
#     10. Работа со структурированными данными в python: создание данных, загрузка, сохранение, чтение, удаление данных.
#     11. Манипулирование данными, обработка прямоугольных данных (таблиц).
#     12. Получение сводных характеристик по прямоугольным данным, OLAP-средства в python
#     13. Меры центральной тенденции: среднее арифметическое, среднее арифметическое взвешенное, среднее гармоническое, геометрическое, усеченное среднее, расчет средних на сгруппированных данных.
#     14. Структурные средние: медиана, мода, квартили.
#     15. Расчет средних характеристик с использованием python, визуализация данных (графики, диаграммы, ящик с усами).
#     16. Проверка гипотез о нормальном законе распределения в python, понятие p-value.
#     17. Понятие корреляционного отношения, линейный коэффицент корреляции Пирсона, проверка его статистической значимости. Построение корреляционных диаграмм.
#     18. Использование ранговых коэффициентов Спирмена, Кендала.
#     19. Анализ качественных признаков
#     20. Канонический корреляционный анализ
#     21. Метод главных компонент
#     22. Кластерный анализ
#     23. Регрессионный анализ, многомерная регрессия
#     24. Дискриминантный анализ
#     25. Метод опорных векторов
