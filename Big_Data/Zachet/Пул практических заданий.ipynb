# %% [markdown]
# # **Пул практических заданий к экзамену**

# %% [markdown]
# 1. По датасету «Сотрудники» рассчитать средний возраст сотрудников в градации по полу. Оценить корреляцию между возрастом и окладом сотрудников.
# 2. По датасету «Специалисты» рассчитать средний должностной оклад, медианное значение оклада за классный чин в градации по группе должностей.
# 3. По датасету «Финансирование» выполнить иерархическую кластеризацию регионов по показателям.
# 4. По датасету «Финансирование» выполнить кластеризацию по алгоритму k-means.
# 5. По датасету «Финансирование» построить уравнение многофакторной регрессии для показателя «Субсидии на ГЗ из федерального бюджета 2015» по трем любым выбранным влияющим факторам.
# 6. По датасету «Специалисты» рассчитать средний должностной оклад, медианное значение оклада за классный чин в градации по группе должностей.
# 7. По датасету «Склад» рассчитать суммарную стоимость товаров в разбивке по коду товара с учетом его цены, количества и скидки.
# 8. По датасету «Организации» с использованием корреляционного анализа оценить взаимосвязь показателей: «Стоимость управления», «Стоимость содержания и ремонта», «Количество домов в управлении», «Площадь помещений в собственности».
# 9. По датасету «Организации» рассчитать суммарное количество домов в градации по управляющей организации, средную площадь помещений в градации по округам.
# 10. По датасету «Наборы конфет»  рассчитать суммарную стоимость наборов конфет с учетом их количества в градации по набору конфет, рассчитать интерквартильный размах веса наборов конфет, сделать вывод об однородности статистической совокупности по весу конфет.
# 11. По датасету «Организации» с использованием построить многофакторную прогнозную модель зависимости округа от следующих показателей: Стоимость управления руб/кв.м, Стоимость содержания и ремонта руб/кв.м, Количество домов в рейтинге, Количество домов в управлении, Площадь помещений в собственности, кв.м.
# 12. По датасету "Музыкальные инструменты" рассчитать суммарную выручку в разбивке по месяцам и магазинам.
# 13. По датасету "Музыкальные инструменты" с использованием метода опорных векторов построить прогнозную модель названия инструмента в зависимости от остальных показателей.

# %%
Variant = 1

import random
random.seed(2026+Variant)

random.randint(1,13)
# Out:
# 2
