# %% [markdown]
# ## **Вопросы к экзамену по дисциплине "Технологии анализа больших данных"**

# %% [markdown]
# ### **Теоретические вопросы**
# 1. Понятие больших данных. Концепция 3V, 5V.
# 2. Краткая хронология становления технологий больших данных.
# 3. Представление о технологии Hadoop Distributed File System.
# 4. Экосистема Hadoop - Pig, Hive, HBase и др.
# 5. Представление о платформе Apache Spark.
# 6. Технологии Apache Kafka и Apache Flink.
# 7. Представление об облачных платформах Amazon Web Services (AWS), Google Cloud Platform (GCP) и Microsoft Azure.
# 8. Понятие NoSQL, классификация NoSQL-решений на примерах Cassandra, MongoDB, Couchbase.
# 9. Ограничения CAP теоремы, формулировка теоремы.
# 10. Основные тренды в формировании представлений о NoSQL.
# 11. Хранилище данных по принципу ключ-значение.
# 12. Документо-ориентированные хранилища данных.
# 13. Графовое хранилище данных.
# 14. Колоночное хранилище данных.
# 15. Технологии шардинга, репликации, разновидности.
# 16. Технология MapReduce.
# 17. OLAP - технологии. Понятия - многомерного анализа, измерения, меры, среза, вращения, консолидации, детализации. Принципы Э. Кодда, определяющие требования к OLAP-анализу.
# 18. Технология EAV.
# 19. Основные команды в операционной системе Linux: общие команды.
# 20. Основные команды в операционной системе Linux: команды работы с файлами.
# 21. Основные команды в операционной системе Linux: права доступа к файлам.
# 22. Основные команды в операционной системе Linux: команды работы с процессами.
# 23. Общие сведения по хранилищу Redis.
# 24. Основные команды и типы данных в Redis.
# 25. Общее описание Redis Cluster. Развертывание Redis кластера. Восстановление после сбоя, шардирование, добавление нового узла, удаление узла, миграция реплик.
# 26. Общая концепция документо-ориентированного хранилища. Установка и настройка MongoDB.
# 27. Основные команды MongoDB. Библиотека Python по работе с MongoDB.
# 28. Горизонтальное масштабирование в MongoDB, репликация.
# 29. Построение кластера MongoDB: набор реплик, конфигурационные сервера, маршрутизаторы.
