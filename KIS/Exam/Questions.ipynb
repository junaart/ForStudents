# 12. Рассматривается работа автозаправочной станции, на которой имеется 2 заправочные колонки. Предположим, что она описывается процессом размножения и гибели в стационарном режиме. Заправка каждой машины длится в среднем 3 мин. В среднем на АЗС каждые 2 мин прибывает машина, нуждающаяся в заправке. Число мест в очереди не ограничено. Все машины, ожидающие заправку, терпеливо дожидаются своей очереди. Определить: вероятность того, что на заправке находится 5 машин; вероятность того, что вновь прибывшей машине придется ждать обслуживания.
# 13. Закусочная на АЗС имеет один прилавок. Автомобили прибывают в соответствии с пуассоновским распределением, в среднем 2 автомобиля за 5 мин. Для выполнения заказа в среднем достаточно 1,5 мин, хотя продолжительность обслуживания распределена по экспоненциальному закону. Найти: вероятность простоя прилавка; средние характеристики; вероятность того, что количество прибывших автомобилей будет не менее 10.
# 14. Рентгеновский аппарат позволяет обследовать в среднем 7 человек в 1 ч. Интенсивность посетителей составляет 5 человек в 1 ч. Предполагая стационарный режим работы, определить средние характеристики.
# 15. В речном порту один причал, интенсивность входного потока – 5 судов в 1 день. Интенсивность погрузочно-разгрузочных работ – 6 судов в 1 день. Имея в виду стационарный режим работы, определить все средние характеристики системы.
# 16. Какое оптимальное число каналов обслуживания должна иметь СМО, если интенсивность потока заявок равна 3, среднее число заявок, обслуженных в единицу времени, равно 2, штраф за каждый отказ равен 5, а стоимость простоя одной линии равна 2?
# 17. Какое оптимальное число каналов обслуживания должна иметь СМО, если интенсивность потока заявок равна 3, среднее число заявок, обслуженных в единицу времени, равно 1, штраф за каждый отказ равен 7, а стоимость простоя одной линии равна 3?
# 18. Какое оптимальное число каналов обслуживания должна иметь СМО, если интенсивность потока заявок равна 4, среднее число заявок, обслуженных в единицу времени, равно 2, штраф за каждый отказ равен 5, а стоимость простоя одной линии равна 1?
# 19. Определить число взлетно-посадочных полос для самолетов с учетом требования, что вероятность ожидания должна быть меньше, чем 0,05. При этом интенсивность входного потока 27 самолетов в 1 сут, а интенсивность их обслуживания – 30 самолетов в 1 сут.
# 20. Сколько равноценных независимых конвейерных линий должен иметь цех, чтобы обеспечить ритм работы, при котором вероятность ожидания обработки изделий должна быть меньше 0,03 (каждое изделие выпускается одной линией). Известно, что интенсивность поступления заказов – 30 изделий в 1 ч, а интенсивность обработки изделия одной линией – 36 изделий в 1 ч.
# 21. Среднее число вызовов, поступающих на АТС за 1 мин, равно 3. Считая поток пуассоновским, найдите вероятность того, что за 2 мин поступит: два вызова; меньше двух вызовов; не менее двух вызовов.
# 22. Сколько каналов должна иметь СМО с отказами, если интенсивность потока заявок равна 2 треб./ч, среднее число заявок, обслуженных в единицу времени, равно 1 треб./ч, штраф за каждый отказ составляет 8 тыс. руб., стоимость простоя одной линии – 2 тыс. руб. в 1 ч?
# 23. Система массового обслуживания представляет собой автоматическую телефонную станцию, которая может обеспечить не более пяти переговоров одновременно. Заявка-вызов, поступившая в тот момент, когда все каналы заняты, получает отказ и покидает систему. В среднем на станцию поступает 0,8 вызовов в 1 мин, а средняя продолжительность одних переговоров равна 1,5 мин. Для стационарного режима функционирования системы необходимо определить: вероятности состояний системы; вероятность отказа; абсолютную пропускную способность; среднее число занятых каналов.

# %% [markdown]
# # Перечень вопросов к зачету

# %% [markdown]
# 1. Введение в дисциплину "Анализ характеристик производительности КИС"
# 2. Общие принципы проектирования и моделирования КИС
# 3. Формализация задач проектирования КИС
# 4. Декомпозиция задач проектирования КИС
# 5. Примеры КИС
# 6. Типовые задачи. Параметры производительности и оперативности КИС
# 7. Общие представления о системах массового обслуживания
# 8. Классификация систем массового обслуживания
# 9. Обозначения СМО (символика Кендалла). Основные определения.
# 10. Преобразование Лапласа-Стилтьеса, производящие функции, их свойства.
# 11. Характеристики систем массового обслуживания
# 12. Марковские процессы, уравнения Колмогорова. Переход от системы дифференциальных уравнений к системе линейных алгебраических уравнений
# 13. Процессы размножения-гибели
# 14. Одноканальная СМО с неограниченной очередью
# 15. Многоканальная СМО с неограниченной очередью
# 16. Одноканальная СМО с отказом
# 17. Многоканальная СМО с отказом
# 18. Одноканальная СМО с ограничением на длину очереди
# 19. Многоканальная СМО с ограничением на длину очереди
# 20. Метод агрегирования с использованием параметров связи
# 21. Агрегирование на основе принципа эквивалентности потоков
# 22. Управление ресурсами в однопроцессорной системе с неоднородными заявками
# 23. Анализ погрешностей с использованием параметров связи
# 24. Анализ погрешностей на основе принципа эквивалентности потоков
# 25. Метод укрупнения состояний марковских моделей
# 26. Дискретное моделирование событий на примере библиотеки Simmer.
# 27. Управление ресурсами в многопроцессорных системах. Алгоритмы Джонсона и  Макнотона.
# 28. Полумарковские процессы, метод вложенных цепей Маркова.
# 29. Вывод формулы Поллачека-Хинчина для среднего систем $M/G/1/\inty$.
# 30. Вывод формулы Поллачека-Хинчина для преобразования систем $M/G/1/\inty$.
# 31. Системы $G/G/1/\infty$ - неравенство Кингмана, формула Файнберга.
# 32. Классификация систем с приоритетами. Примеры анализа.
# 33. Теоремы Кобхэма. Закон сохранения.
# 34. Оптимизация решений на основе моделей массового обслуживания.
