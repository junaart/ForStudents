# %% [markdown]
# # Консультация по вопросам поступления в магистратуру

# %% [markdown]
# 1. Основные понятия теории массового обслуживания. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_2/Lection_2.ipynb)
# 2. Характеристики систем массового обслуживания. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_3/Lection_3.ipynb)
# 3. Временная диаграмма систем массового обслуживания. Результат Литтла. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_3/Lection_3.ipynb)
# 4. Простейшие системы массового обслуживания. Уравнения Колмогорова. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_4/Lection_4.ipynb)
# 5. Математическое ожидание времени пребывания в системе, в обслуживающем приборе, в очереди. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_4/Lection_4.ipynb)
# 6. Математическое ожидание числа требований в системе, в очереди, в обслуживающем приборе. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_4/Lection_4.ipynb)
# 7. Простейшие системы массового обслуживания с произвольным законом обслуживания. Распределение числа требований. Уравнение Поллачека-Хинчина. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_9/Lection_9.ipynb)
# 8. Многоканальные системы массового обслуживания с произвольным законом прибытия и обслуживания. Оценки Марчела-Кингмана. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Books/10099550843054524315544725236567709563.pdf)
# 9. Примеры построения моделей информационных процессов и управления с примерением теории массового обслуживания. [ссылка](https://github.com/junaart/ForStudents/blob/master/KIS/Lection_5/Lection_5.ipynb)

# %% [markdown]
# # Примеры практических заданий

# %% [markdown]
# **Тема: нахождение производящих функций дискретных случайных величин, марковские процессы с дискретным временем**
#
# Каждый час одновременно два программиста A, B независимо друг от друга присылают в буфер сервера по одной программе с заданными вероятностями $P_A=0.7, P_B=0.8$. Программы накапливаются в буфере до тех пор, пока их суммарное количество не превысит 2, после чего программы передаются на сервер, буфер очищается. Считая процесс накопления программ в буфере сервера марковским процессом с дискретным временем, определить долю времени (в процентах) нахождения буфера сервера в состоянии хранения 0, 1, 2 программ (ответ представить с точностью до одного десятичного знака после запятой).
#
# **Тема: марковские процессы с непрерывным временем, уравнения Колмогорова, СМО с отказами.**
#
# Обработка сообщений в специализированной вычислительной системе осуществляется последовательно двумя независимыми программами (сначала первой, потом второй). Длительность работы первой программы представляет собой случайную величину, распределенную по показательному закону распределения с интенсивностью $\mu_1=0.3$, длительность работы второй программы - случайная величина, распределенная по показательному закону с интенсивностью $\mu_2=0.25$. Поток сообщений является простейшим с интенсивностью $\lambda=0.1$. Очередь в системе отсутствует, если первая программа занята, то поступающее сообщение отклоняется, если первая программа обработала сообщение, а вторая все еще занята, сообщение также получает отказ. Найти среднее число сообщений, находящихся в вычислительной системе (ответ представить с точностью до двух десятичных знаков после запятой).
