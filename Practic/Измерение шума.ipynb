# %% [markdown]
# # Основные документы
#
# - ГОСТ 31296.1-2005 Шум. Описание, измерение и оценка шума на местности.
# - СН 2.2.4/2.1.8.562-96 Шум на рабочих местах, в помещениях жилых, общественных зданий и на территории жилой застройки"
#
# Составление шумовой карты городов и агломераций в составе проектов строительства и реконструкции
# объектов должно соответствовать в России требованиям ГОСТ Р 53187-2008 «Акустика. Шумовой мониторинг
# городских территорий» и требованиям строительных норм и правил СНиП 23-03-2003 «Защита от шума», а
# также требованиям соответствующих международных стандартов, директив:
# - Директива 2000/14/ЕС «О шуме оборудования во внешней среде»;
# - Директива 2002/49/ЕС «Об оценке шума в окружающей среде»;
# - Директива 2003/10/ЕС «О требованиях к безопасности и здоровью рабочих под действием шума»;
# - Шуму автотранспорта посвящены Директивы 70/157/EEC, 97/24/EC, 2001/43/EC.
#
# Столичные власти обеспокоены шумом: почти 70 процентов территории Москвы находится в зоне
# шумового дискомфорта. Такие данные обнародованы ГПУ «[Мосэкомониторинг](https://mosecom.mos.ru/)» – организация, которая отвечает за измерение уровня шума в столице.
#
# Пример шумовой карты
#
# ![image.png](attachment:e5250e64-8e2e-422a-8ae1-e5a5684a53e5.png)
#
# Пример аккустических экранов
#
# ![image.png](attachment:9a611f19-eee5-4160-8a74-dcdd03ceb51d.png)
#
# # Понятие шум, классификация шума
#
# Шум — совокупность непериодических звуков различной интенсивности и частоты. С физиологической точки зрения шум — это всякий неблагоприятно воспринимаемый звук.
#
# ![image.png](attachment:1b078574-8bc5-4265-8e5b-ae7ac4af1f90.png)
# ![image.png](attachment:9e38ca38-2006-4d32-8095-9b9da7c896fd.png)

# %% [markdown]
# Белый шум — это монотонный ровный звук, в котором равномерно представлены все частоты слышимого спектра. По восприятию он похож на шум ненастроенного телевизора.
#
# Розовый шум также называют мерцательным или фликкер-шумом. Первоначально его использовали только инженеры-акустики для настройки громкоговорителей или музыкального оборудования на концертах: они проверяли с помощью розового шума пронзительные ноты, которые могли бы плохо звучать для публики. В современности розовый шум часто используют, чтобы замаскировать нежелательные, раздражающие звуки, например, при засыпании или во время работы.
#
# По звучанию розовый шум похож на шелест ветра, сильный дождь, водопад или морские волны. У разных людей возникают свои ассоциации при прослушивании этого низкочастотного звука.
# ![image.png](attachment:4c698cf4-a894-486e-a0f8-4b85560b6d52.png)

# %% [markdown]
# ## Классификация шума
#
#
# 1. По частотной характеристике шумы подразделяются на:
#     - низкочастотный (<300 Гц)
#     - среднечастотный (300—800 Гц)
#     - высокочастотный (>800 Гц)
# 2. По временны́м характеристикам
#     - стационарный;
#     - нестационарный:
#     - колеблющийся;
#     - прерывистый;
#     - импульсный.
# 3. По природе возникновения
#     - Механический
#     - Аэродинамический
#     - Гидравлический
#     - Электромагнитный
#
# Основными физическими параметрами, характеризующими звук, является звуковое давление $Р$ и интенсивность звука $I$. Слуховой аппарат человека реагирует на величину, пропорциональную среднему квадрату звукового
# давления.
# $$P^2 = \frac{1}{T}\cdot \int_0^T P^2(t)dt$$
# $P(t)$ – разность между мгновенными значениями полного давления и средним давлением в среде при отсутствии звукового поля;
# $T$ – время усреднения, которое для уха человека находится в пределах 30-100 мс.
#
# Интенсивностью звука называется количество звуковой энергии, переносимое звуковой волной в единицу времени через единицу поверхности. Звуковое давление измеряется в паскалях (Па), а интенсивность звука – в Вт/м$^2$.
#
# Интенсивность звука связана со звуковым давлением зависимостью:
# $$I=\frac{P^2}{\rho\cdot c}$$
# где $\rho$ – плотность среды (кг/м$^3$);
#
# $С$ – скорость звука (м/с).
#
# **Человек слышит звук в диапазоне частот от 20 Гц до 20 кГц (20000Гц).**
#
# Звук с частотой < 20 Гц - инфразвук.
#
# Звук с частотой > 20 кГц - ультразвук.
#
# Шум, производимый ветроэлектростанциями, также воздействует на среду обитания человека и природы.
#
# 5-10 Гц  - частота резонанса внутренних органов биологических объектов.
#
#
# Область слышимости звуков ограничивается не только определенными частотами, но и определенными значениями давления и интенсивности звука.
#
# Максимальные и минимальные звуковые давления и интенсивности называются пороговыми. Минимальные значения (порог слышимости) соответствуют едва ощущаемым звукам и при частоте 1000 Гц равны $Р_0=2\cdot 10^{-5}$ Па, $I_0= 10^{-12}$ Вт/м$^2$. Звуки, относящиеся к порогу слышимости, воспринимают только люди с уникальным острым слухом (примерно 1% от числа испытуемых). У 50% людей кривая порога слышимости лежит на 15 дБ выше условно принятой средней кривой. Максимальные значения (порог болевого ощущения) соответствуют звукам, которые вызывают в органах слуха болевые ощущения при частоте 1000 Гц равны $Р = 2×10^2$ Па и $I =10^2$ Вт/м$^2$. Таким образом, величины звукового давления и интенсивность звука, которые различает человек, могут меняться в широком диапазоне: по давлению до 107 раз и по интенсивности до 1014 раз. Естественно, что оперировать такими цифрами неудобно. Кроме того, раздражающее действие шума на человека пропорционально не квадрату звукового давления, а логарифму от него. Поэтому, были введены логарифмические величины — уровни звукового давления и
# интенсивности, измеряемые в децибелах (дБ). Так что
#
# $$L = 10 \lg\frac{I}{I_0}=10\lg\frac{P^2}{P_0^2}$$
#
# где $I_0$ и $P_0$ – интенсивность звука и звуковое давление, соответствующие порогу слышимости на частоте 1000 Гц.
#
# Бел – это логарифмическая единица отношения двух величин (десятичный логарифм отношения двух одноименных физических величин, например, мощностей, токов, звукового давления), 0,1 доля Бела – децибел. 1Б=10дБ.
#
# Разговор: 40—45 Дб
# Офис: 50—60 Дб
# Улица: 70—80 Дб
# Фабрика (тяжелая промышленность): 70—110 Дб
# Цепная пила: 100 Дб
# Старт реактивного самолёта: 120 Дб
#
# ![image.png](attachment:e8d3b97b-e950-4075-bc04-40bbc2ac274b.png)
#
# При воздействии шума высоких уровней (более 140 дБ) возможен разрыв барабанных перепонок, контузия, а при ещё более высоких (более 160 дБ) — и смерть.

# %% [markdown]
# # Измерение шума
#
# Для измерения уровня шума применяется прибор **шумомер, частотные анализаторы, коррелометры**. Шумомеры бывают бытовые (диапазоны измерения 30 – 130 дБ, 31,5 Гц – 8 кГц,) и промышленные. Для измерений инфразвуковых и ультразвуковых шумов применяются широкодиапазонные шумомеры.
#
# Одним из важнейших вопросов является зависимость уровня звука от его частоты. Нижняя частотная граница восприятия звука человеком составляет около 30 Гц, а верхняя — не выше 18 кГц; поэтому шумомер должен был бы регистрировать звуки в том же диапазоне частот. Но тут возникает серьезное затруднение. Дело в том что чувствительность человеческого уха для различных частот не одинакова; так, например, чтобы звуки с частотой 30 Гц и 1 кГц звучали одинаково громко, уровень звукового давления первого из них должен быть на 40 дБ выше, чем второго. И следовательно, показания шумомера сами по себе еще не многого стоят.
#
# Поэтому все современные шумомеры снабжены корректирующими контурами, благодаря которым можно снизить чувствительность шумомера к низкочастотным и очень высокочастотным звукам и тем самым приблизить частотные характеристики прибора к свойствам человеческого уха. Обычно шумомер содержит три корректирующих контура, обозначаемых А, В и С; наиболее полезна коррекция А; коррекцию В применяют лишь изредка; и ещё реже коррекцию С.
#
# Чаще всего уровень бытового и промышленного шума принимают равным уровню, измеренному в дБ при помощи шумомера с коррекцией А, и выражают его в единицах дБА. Хотя человеческое ухо воспринимает звук несравненно более утонченно, чем шумомер, и поэтому звуковые уровни, выраженные в дБА, ни в коей мере не соответствуют точно физиологической реакции, но простота этой единицы делает ее чрезвычайно удобной для практического применения.
#
# Ещё одним достоинством шкалы дБА является то обстоятельство, что удвоение громкости грубо соответствует увеличению уровня шума на 10 дБА.
#
# Санитарные нормы СН 2.2.4/2.1.8.562-96 Шум на рабочих местах, в помещениях жилых, общественных зданий и на территории жилой застройки
#
# ![image.png](attachment:246d59bc-4172-45de-ac00-cf091286fcf4.png)
#
# ![image.png](attachment:d119162d-519d-43e0-869b-eaa902d6dc0e.png)
#
# ![image.png](attachment:16743f8a-9622-4f38-ac1d-0a8130160946.png)

# %% [markdown]
# # Постановка задачи измерения шума
#
# **Задача:** измерить уровень шума в каждой функциональной зоне (детская площадка, спортивная площадка, пешеходная зона, парковки, газоны и т.д.).
#
# Если суммарная площадь не более 100 м$^2$, то на каждые 10 м$^2$ выбрать по 9 контрольных точек замера.
#
# Если суммарная площадь больше 100 м$^2$ и не более 1000 м$^2$, то на каждые 100 м$^2$ выбрать по 9 контрольных точек замера.
#
# и т.д.
#
# ![image.png](attachment:bb977b6a-5b21-4bfd-aaf3-094d809f8f70.png)
#
# ![image.png](attachment:861575f3-de3f-410f-8b42-e6ceb6c649d9.png)
